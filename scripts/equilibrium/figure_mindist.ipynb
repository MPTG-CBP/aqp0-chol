# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl

mpl.rcParams['axes.linewidth'] = 3.5 #set the value globally
linew=0.1

# %%
CoM_dist_chol_1=np.loadtxt("xvg_files/chol/1/com_distance.xvg",skiprows=17)
CoM_dist_chol_2=np.loadtxt("xvg_files/chol/2/com_distance.xvg",skiprows=17)
CoM_dist_chol_3=np.loadtxt("xvg_files/chol/3/com_distance.xvg",skiprows=17)
CoM_dist_chol_4=np.loadtxt("xvg_files/chol/4/com_distance.xvg",skiprows=17)
CoM_dist_chol_5=np.loadtxt("xvg_files/chol/5/com_distance.xvg",skiprows=17)
CoM_dist_chol_6=np.loadtxt("xvg_files/chol/6/com_distance.xvg",skiprows=17)
CoM_dist_chol_7=np.loadtxt("xvg_files/chol/7/com_distance.xvg",skiprows=17)
CoM_dist_chol_8=np.loadtxt("xvg_files/chol/8/com_distance.xvg",skiprows=17)
CoM_dist_chol_9=np.loadtxt("xvg_files/chol/9/com_distance.xvg",skiprows=17)
CoM_dist_chol_10=np.loadtxt("xvg_files/chol/10/com_distance.xvg",skiprows=17)

CoM_dist_nochol_1=np.loadtxt("xvg_files/no_chol/1/distances.xvg",skiprows=17)
CoM_dist_nochol_2=np.loadtxt("xvg_files/no_chol/2/distances.xvg",skiprows=17)
CoM_dist_nochol_3=np.loadtxt("xvg_files/no_chol/3/distances.xvg",skiprows=17)
CoM_dist_nochol_4=np.loadtxt("xvg_files/no_chol/4/distances.xvg",skiprows=17)
CoM_dist_nochol_5=np.loadtxt("xvg_files/no_chol/5/distances.xvg",skiprows=17)
CoM_dist_nochol_6=np.loadtxt("xvg_files/no_chol/6/distances.xvg",skiprows=17)
CoM_dist_nochol_7=np.loadtxt("xvg_files/no_chol/7/distances.xvg",skiprows=17)
CoM_dist_nochol_8=np.loadtxt("xvg_files/no_chol/8/distances.xvg",skiprows=17)
CoM_dist_nochol_9=np.loadtxt("xvg_files/no_chol/9/distances.xvg",skiprows=17)
CoM_dist_nochol_10=np.loadtxt("xvg_files/no_chol/10/distances.xvg",skiprows=17)

# %%
tet_dist_chol_1=np.loadtxt("xvg_files/chol/1/tet_mindist.xvg",skiprows=24)
tet_dist_chol_2=np.loadtxt("xvg_files/chol/2/tet_mindist.xvg",skiprows=24)
tet_dist_chol_3=np.loadtxt("xvg_files/chol/3/tet_mindist.xvg",skiprows=24)
tet_dist_chol_4=np.loadtxt("xvg_files/chol/4/tet_mindist.xvg",skiprows=24)
tet_dist_chol_5=np.loadtxt("xvg_files/chol/5/tet_mindist.xvg",skiprows=24)
tet_dist_chol_6=np.loadtxt("xvg_files/chol/6/tet_mindist.xvg",skiprows=24)
tet_dist_chol_7=np.loadtxt("xvg_files/chol/7/tet_mindist.xvg",skiprows=24)
tet_dist_chol_8=np.loadtxt("xvg_files/chol/8/tet_mindist.xvg",skiprows=24)
tet_dist_chol_9=np.loadtxt("xvg_files/chol/9/tet_mindist.xvg",skiprows=24)
tet_dist_chol_10=np.loadtxt("xvg_files/chol/10/tet_mindist.xvg",skiprows=24)

tet_dist_nochol_1=np.loadtxt("xvg_files/no_chol/1/tet_mindist.xvg",skiprows=24)
tet_dist_nochol_2=np.loadtxt("xvg_files/no_chol/2/tet_mindist.xvg",skiprows=24)
tet_dist_nochol_3=np.loadtxt("xvg_files/no_chol/3/tet_mindist.xvg",skiprows=24)
tet_dist_nochol_4=np.loadtxt("xvg_files/no_chol/4/tet_mindist.xvg",skiprows=24)
tet_dist_nochol_5=np.loadtxt("xvg_files/no_chol/5/tet_mindist.xvg",skiprows=24)
tet_dist_nochol_6=np.loadtxt("xvg_files/no_chol/6/tet_mindist.xvg",skiprows=24)
tet_dist_nochol_7=np.loadtxt("xvg_files/no_chol/7/tet_mindist.xvg",skiprows=24)
tet_dist_nochol_8=np.loadtxt("xvg_files/no_chol/8/tet_mindist.xvg",skiprows=24)
tet_dist_nochol_9=np.loadtxt("xvg_files/no_chol/9/tet_mindist.xvg",skiprows=24)
tet_dist_nochol_10=np.loadtxt("xvg_files/no_chol/10/tet_mindist.xvg",skiprows=24)

# %%
cont_chol_1=np.loadtxt("xvg_files/chol/1/tet_numcont.xvg",skiprows=24)
cont_chol_2=np.loadtxt("xvg_files/chol/2/tet_numcont.xvg",skiprows=24)
cont_chol_3=np.loadtxt("xvg_files/chol/3/tet_numcont.xvg",skiprows=24)
cont_chol_4=np.loadtxt("xvg_files/chol/4/tet_numcont.xvg",skiprows=24)
cont_chol_5=np.loadtxt("xvg_files/chol/5/tet_numcont.xvg",skiprows=24)
cont_chol_6=np.loadtxt("xvg_files/chol/6/tet_numcont.xvg",skiprows=24)
cont_chol_7=np.loadtxt("xvg_files/chol/7/tet_numcont.xvg",skiprows=24)
cont_chol_8=np.loadtxt("xvg_files/chol/8/tet_numcont.xvg",skiprows=24)
cont_chol_9=np.loadtxt("xvg_files/chol/9/tet_numcont.xvg",skiprows=24)
cont_chol_10=np.loadtxt("xvg_files/chol/10/tet_numcont.xvg",skiprows=24)

cont_nochol_1=np.loadtxt("xvg_files/no_chol/1/tet_numcont.xvg",skiprows=24)
cont_nochol_2=np.loadtxt("xvg_files/no_chol/2/tet_numcont.xvg",skiprows=24)
cont_nochol_3=np.loadtxt("xvg_files/no_chol/3/tet_numcont.xvg",skiprows=24)
cont_nochol_4=np.loadtxt("xvg_files/no_chol/4/tet_numcont.xvg",skiprows=24)
cont_nochol_5=np.loadtxt("xvg_files/no_chol/5/tet_numcont.xvg",skiprows=24)
cont_nochol_6=np.loadtxt("xvg_files/no_chol/6/tet_numcont.xvg",skiprows=24)
cont_nochol_7=np.loadtxt("xvg_files/no_chol/7/tet_numcont.xvg",skiprows=24)
cont_nochol_8=np.loadtxt("xvg_files/no_chol/8/tet_numcont.xvg",skiprows=24)
cont_nochol_9=np.loadtxt("xvg_files/no_chol/9/tet_numcont.xvg",skiprows=24)
cont_nochol_10=np.loadtxt("xvg_files/no_chol/10/tet_numcont.xvg",skiprows=24)

# %%
cont_fix_chol_1=np.loadtxt("xvg_files_fix/chol/1/tet_numcont_fix.xvg",skiprows=24)
cont_fix_chol_2=np.loadtxt("xvg_files_fix/chol/2/tet_numcont_fix.xvg",skiprows=24)
cont_fix_chol_3=np.loadtxt("xvg_files_fix/chol/3/tet_numcont_fix.xvg",skiprows=24)
cont_fix_chol_4=np.loadtxt("xvg_files_fix/chol/4/tet_numcont_fix.xvg",skiprows=24)
cont_fix_chol_5=np.loadtxt("xvg_files_fix/chol/5/tet_numcont_fix.xvg",skiprows=24)
cont_fix_chol_6=np.loadtxt("xvg_files_fix/chol/6/tet_numcont_fix.xvg",skiprows=24)
cont_fix_chol_7=np.loadtxt("xvg_files_fix/chol/7/tet_numcont_fix.xvg",skiprows=24)
cont_fix_chol_8=np.loadtxt("xvg_files_fix/chol/8/tet_numcont_fix.xvg",skiprows=24)
cont_fix_chol_9=np.loadtxt("xvg_files_fix/chol/9/tet_numcont_fix.xvg",skiprows=24)
cont_fix_chol_10=np.loadtxt("xvg_files_fix/chol/10/tet_numcont_fix.xvg",skiprows=24)

cont_fix_nochol_1=np.loadtxt("xvg_files_fix/no_chol/1/tet_numcont_fix.xvg",skiprows=24)
cont_fix_nochol_2=np.loadtxt("xvg_files_fix/no_chol/2/tet_numcont_fix.xvg",skiprows=24)
cont_fix_nochol_3=np.loadtxt("xvg_files_fix/no_chol/3/tet_numcont_fix.xvg",skiprows=24)
cont_fix_nochol_4=np.loadtxt("xvg_files_fix/no_chol/4/tet_numcont_fix.xvg",skiprows=24)
cont_fix_nochol_5=np.loadtxt("xvg_files_fix/no_chol/5/tet_numcont_fix.xvg",skiprows=24)
cont_fix_nochol_6=np.loadtxt("xvg_files_fix/no_chol/6/tet_numcont_fix.xvg",skiprows=24)
cont_fix_nochol_7=np.loadtxt("xvg_files_fix/no_chol/7/tet_numcont_fix.xvg",skiprows=24)
cont_fix_nochol_8=np.loadtxt("xvg_files_fix/no_chol/8/tet_numcont_fix.xvg",skiprows=24)
cont_fix_nochol_9=np.loadtxt("xvg_files_fix/no_chol/9/tet_numcont_fix.xvg",skiprows=24)
cont_fix_nochol_10=np.loadtxt("xvg_files_fix/no_chol/10/tet_numcont_fix.xvg",skiprows=24)

# %%
CoM_dist_fix_chol_1=np.loadtxt("xvg_files_fix/chol/1/com_distance_fix.xvg",skiprows=17)
CoM_dist_fix_chol_2=np.loadtxt("xvg_files_fix/chol/2/com_distance_fix.xvg",skiprows=17)
CoM_dist_fix_chol_3=np.loadtxt("xvg_files_fix/chol/3/com_distance_fix.xvg",skiprows=17)
CoM_dist_fix_chol_4=np.loadtxt("xvg_files_fix/chol/4/com_distance_fix.xvg",skiprows=17)
CoM_dist_fix_chol_5=np.loadtxt("xvg_files_fix/chol/5/com_distance_fix.xvg",skiprows=17)
CoM_dist_fix_chol_6=np.loadtxt("xvg_files_fix/chol/6/com_distance_fix.xvg",skiprows=17)
CoM_dist_fix_chol_7=np.loadtxt("xvg_files_fix/chol/7/com_distance_fix.xvg",skiprows=17)
CoM_dist_fix_chol_8=np.loadtxt("xvg_files_fix/chol/8/com_distance_fix.xvg",skiprows=17)
CoM_dist_fix_chol_9=np.loadtxt("xvg_files_fix/chol/9/com_distance_fix.xvg",skiprows=17)
CoM_dist_fix_chol_10=np.loadtxt("xvg_files_fix/chol/10/com_distance_fix.xvg",skiprows=17)

CoM_dist_fix_nochol_1=np.loadtxt("xvg_files_fix/no_chol/1/distances_fix.xvg",skiprows=17)
CoM_dist_fix_nochol_2=np.loadtxt("xvg_files_fix/no_chol/2/distances_fix.xvg",skiprows=17)
CoM_dist_fix_nochol_3=np.loadtxt("xvg_files_fix/no_chol/3/distances_fix.xvg",skiprows=17)
CoM_dist_fix_nochol_4=np.loadtxt("xvg_files_fix/no_chol/4/distances_fix.xvg",skiprows=17)
CoM_dist_fix_nochol_5=np.loadtxt("xvg_files_fix/no_chol/5/distances_fix.xvg",skiprows=17)
CoM_dist_fix_nochol_6=np.loadtxt("xvg_files_fix/no_chol/6/distances_fix.xvg",skiprows=17)
CoM_dist_fix_nochol_7=np.loadtxt("xvg_files_fix/no_chol/7/distances_fix.xvg",skiprows=17)
CoM_dist_fix_nochol_8=np.loadtxt("xvg_files_fix/no_chol/8/distances_fix.xvg",skiprows=17)
CoM_dist_fix_nochol_9=np.loadtxt("xvg_files_fix/no_chol/9/distances_fix.xvg",skiprows=17)
CoM_dist_fix_nochol_10=np.loadtxt("xvg_files_fix/no_chol/10/distances_fix.xvg",skiprows=17)

tet_dist_fix_chol_1=np.loadtxt("xvg_files_fix/chol/1/tet_mindist_fix.xvg",skiprows=24)
tet_dist_fix_chol_2=np.loadtxt("xvg_files_fix/chol/2/tet_mindist_fix.xvg",skiprows=24)
tet_dist_fix_chol_3=np.loadtxt("xvg_files_fix/chol/3/tet_mindist_fix.xvg",skiprows=24)
tet_dist_fix_chol_4=np.loadtxt("xvg_files_fix/chol/4/tet_mindist_fix.xvg",skiprows=24)
tet_dist_fix_chol_5=np.loadtxt("xvg_files_fix/chol/5/tet_mindist_fix.xvg",skiprows=24)
tet_dist_fix_chol_6=np.loadtxt("xvg_files_fix/chol/6/tet_mindist_fix.xvg",skiprows=24)
tet_dist_fix_chol_7=np.loadtxt("xvg_files_fix/chol/7/tet_mindist_fix.xvg",skiprows=24)
tet_dist_fix_chol_8=np.loadtxt("xvg_files_fix/chol/8/tet_mindist_fix.xvg",skiprows=24)
tet_dist_fix_chol_9=np.loadtxt("xvg_files_fix/chol/9/tet_mindist_fix.xvg",skiprows=24)
tet_dist_fix_chol_10=np.loadtxt("xvg_files_fix/chol/10/tet_mindist_fix.xvg",skiprows=24)

tet_dist_fix_nochol_1=np.loadtxt("xvg_files_fix/no_chol/1/tet_mindist_fix.xvg",skiprows=24)
tet_dist_fix_nochol_2=np.loadtxt("xvg_files_fix/no_chol/2/tet_mindist_fix.xvg",skiprows=24)
tet_dist_fix_nochol_3=np.loadtxt("xvg_files_fix/no_chol/3/tet_mindist_fix.xvg",skiprows=24)
tet_dist_fix_nochol_4=np.loadtxt("xvg_files_fix/no_chol/4/tet_mindist_fix.xvg",skiprows=24)
tet_dist_fix_nochol_5=np.loadtxt("xvg_files_fix/no_chol/5/tet_mindist_fix.xvg",skiprows=24)
tet_dist_fix_nochol_6=np.loadtxt("xvg_files_fix/no_chol/6/tet_mindist_fix.xvg",skiprows=24)
tet_dist_fix_nochol_7=np.loadtxt("xvg_files_fix/no_chol/7/tet_mindist_fix.xvg",skiprows=24)
tet_dist_fix_nochol_8=np.loadtxt("xvg_files_fix/no_chol/8/tet_mindist_fix.xvg",skiprows=24)
tet_dist_fix_nochol_9=np.loadtxt("xvg_files_fix/no_chol/9/tet_mindist_fix.xvg",skiprows=24)
tet_dist_fix_nochol_10=np.loadtxt("xvg_files_fix/no_chol/10/tet_mindist_fix.xvg",skiprows=24)

# %%
lowcut=6
highcut=6.95

# %%
plt.figure(figsize=(12,8))
plt.scatter(0.001*CoM_dist_chol_1[:,0],CoM_dist_chol_1[:,1],color="blue",lw=linew,label="Chol.")
plt.scatter(0.001*CoM_dist_chol_1[np.where(CoM_dist_chol_1[:,1]>3)[0],0],CoM_dist_chol_1[np.where(CoM_dist_chol_1[:,1]>3)[0],1],color="blue")
plt.scatter(0.001*CoM_dist_chol_3[:,0],CoM_dist_chol_3[:,1],color="blue")
plt.scatter(0.001*CoM_dist_chol_4[:,0],CoM_dist_chol_4[:,1],color="blue")
plt.scatter(0.001*CoM_dist_chol_5[:,0],CoM_dist_chol_5[:,1],color="blue")
plt.scatter(0.001*CoM_dist_chol_6[:,0],CoM_dist_chol_6[:,1],color="blue")
plt.scatter(0.001*CoM_dist_chol_7[:,0],CoM_dist_chol_7[:,1],color="blue")
plt.scatter(0.001*CoM_dist_chol_8[:,0],CoM_dist_chol_8[:,1],color="blue")
plt.scatter(0.001*CoM_dist_chol_9[:,0],CoM_dist_chol_9[:,1],color="blue")
plt.scatter(0.001*CoM_dist_chol_10[:,0],CoM_dist_chol_10[:,1],color="blue")
plt.scatter(0.001*CoM_dist_nochol_1[:,0],CoM_dist_nochol_1[:,1],color="red",lw=linew,label="PSM")
plt.scatter(0.001*CoM_dist_nochol_2[:,0],CoM_dist_nochol_2[:,1],color="red")
plt.scatter(0.001*CoM_dist_nochol_3[:,0],CoM_dist_nochol_3[:,1],color="red")
plt.scatter(0.001*CoM_dist_nochol_4[:,0],CoM_dist_nochol_4[:,1],color="red")
plt.scatter(0.001*CoM_dist_nochol_5[:,0],CoM_dist_nochol_5[:,1],color="red")
plt.scatter(0.001*CoM_dist_nochol_6[:,0],CoM_dist_nochol_6[:,1],color="red")
plt.scatter(0.001*CoM_dist_nochol_7[:,0],CoM_dist_nochol_7[:,1],color="red")
plt.scatter(0.001*CoM_dist_nochol_8[:,0],CoM_dist_nochol_8[:,1],color="red")
plt.scatter(0.001*CoM_dist_nochol_9[:,0],CoM_dist_nochol_9[:,1],color="red")
plt.scatter(0.001*CoM_dist_nochol_10[:,0],CoM_dist_nochol_10[:,1],color="red")
plt.tick_params(axis='both', which='both', labelsize=32, length=6, width=4)
plt.legend(fontsize=32)
plt.xlabel("Time (ns)",fontsize=36)
plt.ylabel("$d_{CM}$ (nm)",fontsize=36)
plt.xlim(900, 1000)
#plt.ylim(6.9,7.1)
#plt.ylim(6.9,6.95)
plt.savefig("AQP0_figS2_CMdist_saltos.png", bbox_inches="tight")

# %%
"""
print(1)
print(np.any(CoM_dist_chol_1[:,1]<4))
print(2)
print(np.any(CoM_dist_chol_2[:,1]<4))
print(3)
print(np.any(CoM_dist_chol_3[:,1]<4))
print(4)
print(np.any(CoM_dist_chol_4[:,1]<4))
print(5)
print(np.any(CoM_dist_chol_5[:,1]<4))
print(6)
print(np.any(CoM_dist_chol_6[:,1]<4))
print(7)
print(np.any(CoM_dist_chol_7[:,1]<4))
print(8)
print(np.any(CoM_dist_chol_8[:,1]<4))
print(9)
print(np.any(CoM_dist_chol_9[:,1]<4))
print(10)
print(np.any(CoM_dist_chol_10[:,1]<4))
"""
print(np.any(CoM_dist_nochol_1[np.where(CoM_dist_nochol_1[:,1]>3)[0],1]<6.5))
print(np.any(CoM_dist_nochol_2[np.where(CoM_dist_nochol_2[:,1]>3)[0],1]<6.5))
print(np.any(CoM_dist_nochol_3[np.where(CoM_dist_nochol_3[:,1]>3)[0],1]<6.5))
print(np.any(CoM_dist_nochol_4[np.where(CoM_dist_nochol_4[:,1]>3)[0],1]<6.5))
print(np.any(CoM_dist_nochol_5[np.where(CoM_dist_nochol_5[:,1]>3)[0],1]<6.5))
print(np.any(CoM_dist_nochol_6[np.where(CoM_dist_nochol_6[:,1]>3)[0],1]<6.5))
print(np.any(CoM_dist_nochol_7[np.where(CoM_dist_nochol_7[:,1]>3)[0],1]<6.5))
print(np.any(CoM_dist_nochol_8[np.where(CoM_dist_nochol_8[:,1]>3)[0],1]<6.5))
print(np.any(CoM_dist_nochol_9[np.where(CoM_dist_nochol_9[:,1]>3)[0],1]<6.5))
print(np.any(CoM_dist_nochol_10[np.where(CoM_dist_nochol_10[:,1]>3)[0],1]<6.5))
# Out:
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False

# %%
plt.figure(figsize=(12,8))
plt.plot(0.001*CoM_dist_chol_1[np.where((CoM_dist_chol_1[:,1]>lowcut) & (CoM_dist_chol_1[:,1]<highcut))[0],0],CoM_dist_chol_1[np.where((CoM_dist_chol_1[:,1]>lowcut) & (CoM_dist_chol_1[:,1]<highcut))[0],1],color="blue",lw=linew,label="Chol")
plt.plot(0.001*CoM_dist_chol_2[np.where((CoM_dist_chol_2[:,1]>lowcut) & (CoM_dist_chol_2[:,1]<highcut))[0],0],CoM_dist_chol_2[np.where((CoM_dist_chol_2[:,1]>lowcut) & (CoM_dist_chol_2[:,1]<highcut))[0],1],color="blue",lw=linew)
plt.plot(0.001*CoM_dist_chol_3[np.where((CoM_dist_chol_3[:,1]>lowcut) & (CoM_dist_chol_3[:,1]<highcut))[0],0],CoM_dist_chol_3[np.where((CoM_dist_chol_3[:,1]>lowcut) & (CoM_dist_chol_3[:,1]<highcut))[0],1],color="blue",lw=linew)
plt.plot(0.001*CoM_dist_chol_4[np.where((CoM_dist_chol_4[:,1]>lowcut) & (CoM_dist_chol_4[:,1]<highcut))[0],0],CoM_dist_chol_4[np.where((CoM_dist_chol_4[:,1]>lowcut) & (CoM_dist_chol_4[:,1]<highcut))[0],1],color="blue",lw=linew)
plt.plot(0.001*CoM_dist_chol_5[np.where((CoM_dist_chol_5[:,1]>lowcut) & (CoM_dist_chol_5[:,1]<highcut))[0],0],CoM_dist_chol_5[np.where((CoM_dist_chol_5[:,1]>lowcut) & (CoM_dist_chol_5[:,1]<highcut))[0],1],color="blue",lw=linew)
plt.plot(0.001*CoM_dist_chol_6[np.where((CoM_dist_chol_6[:,1]>lowcut) & (CoM_dist_chol_6[:,1]<highcut))[0],0],CoM_dist_chol_6[np.where((CoM_dist_chol_6[:,1]>lowcut) & (CoM_dist_chol_6[:,1]<highcut))[0],1],color="blue",lw=linew)
plt.plot(0.001*CoM_dist_chol_7[np.where((CoM_dist_chol_7[:,1]>lowcut) & (CoM_dist_chol_7[:,1]<highcut))[0],0],CoM_dist_chol_7[np.where((CoM_dist_chol_7[:,1]>lowcut) & (CoM_dist_chol_7[:,1]<highcut))[0],1],color="blue",lw=linew)
plt.plot(0.001*CoM_dist_chol_8[np.where((CoM_dist_chol_8[:,1]>lowcut) & (CoM_dist_chol_8[:,1]<highcut))[0],0],CoM_dist_chol_8[np.where((CoM_dist_chol_8[:,1]>lowcut) & (CoM_dist_chol_8[:,1]<highcut))[0],1],color="blue",lw=linew)
plt.plot(0.001*CoM_dist_chol_9[np.where((CoM_dist_chol_9[:,1]>lowcut) & (CoM_dist_chol_9[:,1]<highcut))[0],0],CoM_dist_chol_9[np.where((CoM_dist_chol_9[:,1]>lowcut) & (CoM_dist_chol_9[:,1]<highcut))[0],1],color="blue",lw=linew)
plt.plot(0.001*CoM_dist_chol_10[np.where((CoM_dist_chol_10[:,1]>lowcut) & (CoM_dist_chol_10[:,1]<highcut))[0],0],CoM_dist_chol_10[np.where((CoM_dist_chol_10[:,1]>lowcut) & (CoM_dist_chol_10[:,1]<highcut))[0],1],color="blue",lw=linew)
plt.plot(0.001*CoM_dist_nochol_1[np.where((CoM_dist_nochol_1[:,1]>lowcut) & (CoM_dist_nochol_1[:,1]<highcut))[0],0],CoM_dist_nochol_1[np.where((CoM_dist_nochol_1[:,1]>lowcut) & (CoM_dist_nochol_1[:,1]<highcut))[0],1],color="red",lw=linew,label="PSM")
plt.plot(0.001*CoM_dist_nochol_2[np.where((CoM_dist_nochol_2[:,1]>lowcut) & (CoM_dist_nochol_2[:,1]<highcut))[0],0],CoM_dist_nochol_2[np.where((CoM_dist_nochol_2[:,1]>lowcut) & (CoM_dist_nochol_2[:,1]<highcut))[0],1],color="red",lw=linew)
plt.plot(0.001*CoM_dist_nochol_3[np.where((CoM_dist_nochol_3[:,1]>lowcut) & (CoM_dist_nochol_3[:,1]<highcut))[0],0],CoM_dist_nochol_3[np.where((CoM_dist_nochol_3[:,1]>lowcut) & (CoM_dist_nochol_3[:,1]<highcut))[0],1],color="red",lw=linew)
plt.plot(0.001*CoM_dist_nochol_4[np.where((CoM_dist_nochol_4[:,1]>lowcut) & (CoM_dist_nochol_4[:,1]<highcut))[0],0],CoM_dist_nochol_4[np.where((CoM_dist_nochol_4[:,1]>lowcut) & (CoM_dist_nochol_4[:,1]<highcut))[0],1],color="red",lw=linew)
plt.plot(0.001*CoM_dist_nochol_5[np.where((CoM_dist_nochol_5[:,1]>lowcut) & (CoM_dist_nochol_5[:,1]<highcut))[0],0],CoM_dist_nochol_5[np.where((CoM_dist_nochol_5[:,1]>lowcut) & (CoM_dist_nochol_5[:,1]<highcut))[0],1],color="red",lw=linew)
plt.plot(0.001*CoM_dist_nochol_6[np.where((CoM_dist_nochol_6[:,1]>lowcut) & (CoM_dist_nochol_6[:,1]<highcut))[0],0],CoM_dist_nochol_6[np.where((CoM_dist_nochol_6[:,1]>lowcut) & (CoM_dist_nochol_6[:,1]<highcut))[0],1],color="red",lw=linew)
plt.plot(0.001*CoM_dist_nochol_7[np.where((CoM_dist_nochol_7[:,1]>lowcut) & (CoM_dist_nochol_7[:,1]<highcut))[0],0],CoM_dist_nochol_7[np.where((CoM_dist_nochol_7[:,1]>lowcut) & (CoM_dist_nochol_7[:,1]<highcut))[0],1],color="red",lw=linew)
plt.plot(0.001*CoM_dist_nochol_8[np.where((CoM_dist_nochol_8[:,1]>lowcut) & (CoM_dist_nochol_8[:,1]<highcut))[0],0],CoM_dist_nochol_8[np.where((CoM_dist_nochol_8[:,1]>lowcut) & (CoM_dist_nochol_8[:,1]<highcut))[0],1],color="red",lw=linew)
plt.plot(0.001*CoM_dist_nochol_9[np.where((CoM_dist_nochol_9[:,1]>lowcut) & (CoM_dist_nochol_9[:,1]<highcut))[0],0],CoM_dist_nochol_9[np.where((CoM_dist_nochol_9[:,1]>lowcut) & (CoM_dist_nochol_9[:,1]<highcut))[0],1],color="red",lw=linew)
plt.plot(0.001*CoM_dist_nochol_10[np.where((CoM_dist_nochol_10[:,1]>lowcut) & (CoM_dist_nochol_10[:,1]<highcut))[0],0],CoM_dist_nochol_10[np.where((CoM_dist_nochol_10[:,1]>lowcut) & (CoM_dist_nochol_10[:,1]<highcut))[0],1],color="red",lw=linew)
plt.tick_params(axis='both', which='both', labelsize=32, length=6, width=4)
plt.legend(fontsize=32)
plt.xlabel("Time (ns)",fontsize=36)
plt.ylabel("$d_{CM}$ (nm)",fontsize=36)
plt.xlim(0, 1000)
#plt.ylim(6.7, 6.95)
plt.savefig("AQP0_figS2_CMdist.png", bbox_inches="tight")

# %%
lowcut_tet=0
highcut_tet=10
plt.figure(figsize=(12,8))
plt.plot(0.001*tet_dist_chol_1[np.where((tet_dist_chol_1[:,1]>lowcut_tet) & (tet_dist_chol_1[:,1]<highcut_tet))[0],0],tet_dist_chol_1[np.where((tet_dist_chol_1[:,1]>lowcut_tet) & (tet_dist_chol_1[:,1]<highcut_tet))[0],1],color="blue",lw=linew,label="Chol")
plt.plot(0.001*tet_dist_chol_2[np.where((tet_dist_chol_2[:,1]>lowcut_tet) & (tet_dist_chol_2[:,1]<highcut_tet))[0],0],tet_dist_chol_2[np.where((tet_dist_chol_2[:,1]>lowcut_tet) & (tet_dist_chol_2[:,1]<highcut_tet))[0],1],color="blue",lw=linew)
plt.plot(0.001*tet_dist_chol_3[np.where((tet_dist_chol_3[:,1]>lowcut_tet) & (tet_dist_chol_3[:,1]<highcut_tet))[0],0],tet_dist_chol_3[np.where((tet_dist_chol_3[:,1]>lowcut_tet) & (tet_dist_chol_3[:,1]<highcut_tet))[0],1],color="blue",lw=linew)
plt.plot(0.001*tet_dist_chol_4[np.where((tet_dist_chol_4[:,1]>lowcut_tet) & (tet_dist_chol_4[:,1]<highcut_tet))[0],0],tet_dist_chol_4[np.where((tet_dist_chol_4[:,1]>lowcut_tet) & (tet_dist_chol_4[:,1]<highcut_tet))[0],1],color="blue",lw=linew)
plt.plot(0.001*tet_dist_chol_5[np.where((tet_dist_chol_5[:,1]>lowcut_tet) & (tet_dist_chol_5[:,1]<highcut_tet))[0],0],tet_dist_chol_5[np.where((tet_dist_chol_5[:,1]>lowcut_tet) & (tet_dist_chol_5[:,1]<highcut_tet))[0],1],color="blue",lw=linew)
plt.plot(0.001*tet_dist_chol_6[np.where((tet_dist_chol_6[:,1]>lowcut_tet) & (tet_dist_chol_6[:,1]<highcut_tet))[0],0],tet_dist_chol_6[np.where((tet_dist_chol_6[:,1]>lowcut_tet) & (tet_dist_chol_6[:,1]<highcut_tet))[0],1],color="blue",lw=linew)
plt.plot(0.001*tet_dist_chol_7[np.where((tet_dist_chol_7[:,1]>lowcut_tet) & (tet_dist_chol_7[:,1]<highcut_tet))[0],0],tet_dist_chol_7[np.where((tet_dist_chol_7[:,1]>lowcut_tet) & (tet_dist_chol_7[:,1]<highcut_tet))[0],1],color="blue",lw=linew)
plt.plot(0.001*tet_dist_chol_8[np.where((tet_dist_chol_8[:,1]>lowcut_tet) & (tet_dist_chol_8[:,1]<highcut_tet))[0],0],tet_dist_chol_8[np.where((tet_dist_chol_8[:,1]>lowcut_tet) & (tet_dist_chol_8[:,1]<highcut_tet))[0],1],color="blue",lw=linew)
plt.plot(0.001*tet_dist_chol_9[np.where((tet_dist_chol_9[:,1]>lowcut_tet) & (tet_dist_chol_9[:,1]<highcut_tet))[0],0],tet_dist_chol_9[np.where((tet_dist_chol_9[:,1]>lowcut_tet) & (tet_dist_chol_9[:,1]<highcut_tet))[0],1],color="blue",lw=linew)
plt.plot(0.001*tet_dist_chol_10[np.where((tet_dist_chol_10[:,1]>lowcut_tet) & (tet_dist_chol_10[:,1]<highcut_tet))[0],0],tet_dist_chol_10[np.where((tet_dist_chol_10[:,1]>lowcut_tet) & (tet_dist_chol_10[:,1]<highcut_tet))[0],1],color="blue",lw=linew)
plt.plot(0.001*tet_dist_nochol_1[np.where((tet_dist_nochol_1[:,1]>lowcut_tet) & (tet_dist_nochol_1[:,1]<highcut_tet))[0],0],tet_dist_nochol_1[np.where((tet_dist_nochol_1[:,1]>lowcut_tet) & (tet_dist_nochol_1[:,1]<highcut_tet))[0],1],color="red",lw=linew,label="PSM")
plt.plot(0.001*tet_dist_nochol_2[np.where((tet_dist_nochol_2[:,1]>lowcut_tet) & (tet_dist_nochol_2[:,1]<highcut_tet))[0],0],tet_dist_nochol_2[np.where((tet_dist_nochol_2[:,1]>lowcut_tet) & (tet_dist_nochol_2[:,1]<highcut_tet))[0],1],color="red",lw=linew)
plt.plot(0.001*tet_dist_nochol_3[np.where((tet_dist_nochol_3[:,1]>lowcut_tet) & (tet_dist_nochol_3[:,1]<highcut_tet))[0],0],tet_dist_nochol_3[np.where((tet_dist_nochol_3[:,1]>lowcut_tet) & (tet_dist_nochol_3[:,1]<highcut_tet))[0],1],color="red",lw=linew)
plt.plot(0.001*tet_dist_nochol_4[np.where((tet_dist_nochol_4[:,1]>lowcut_tet) & (tet_dist_nochol_4[:,1]<highcut_tet))[0],0],tet_dist_nochol_4[np.where((tet_dist_nochol_4[:,1]>lowcut_tet) & (tet_dist_nochol_4[:,1]<highcut_tet))[0],1],color="red",lw=linew)
plt.plot(0.001*tet_dist_nochol_5[np.where((tet_dist_nochol_5[:,1]>lowcut_tet) & (tet_dist_nochol_5[:,1]<highcut_tet))[0],0],tet_dist_nochol_5[np.where((tet_dist_nochol_5[:,1]>lowcut_tet) & (tet_dist_nochol_5[:,1]<highcut_tet))[0],1],color="red",lw=linew)
plt.plot(0.001*tet_dist_nochol_6[np.where((tet_dist_nochol_6[:,1]>lowcut_tet) & (tet_dist_nochol_6[:,1]<highcut_tet))[0],0],tet_dist_nochol_6[np.where((tet_dist_nochol_6[:,1]>lowcut_tet) & (tet_dist_nochol_6[:,1]<highcut_tet))[0],1],color="red",lw=linew)
plt.plot(0.001*tet_dist_nochol_7[np.where((tet_dist_nochol_7[:,1]>lowcut_tet) & (tet_dist_nochol_7[:,1]<highcut_tet))[0],0],tet_dist_nochol_7[np.where((tet_dist_nochol_7[:,1]>lowcut_tet) & (tet_dist_nochol_7[:,1]<highcut_tet))[0],1],color="red",lw=linew)
plt.plot(0.001*tet_dist_nochol_8[np.where((tet_dist_nochol_8[:,1]>lowcut_tet) & (tet_dist_nochol_8[:,1]<highcut_tet))[0],0],tet_dist_nochol_8[np.where((tet_dist_nochol_8[:,1]>lowcut_tet) & (tet_dist_nochol_8[:,1]<highcut_tet))[0],1],color="red",lw=linew)
plt.plot(0.001*tet_dist_nochol_9[np.where((tet_dist_nochol_9[:,1]>lowcut_tet) & (tet_dist_nochol_9[:,1]<highcut_tet))[0],0],tet_dist_nochol_9[np.where((tet_dist_nochol_9[:,1]>lowcut_tet) & (tet_dist_nochol_9[:,1]<highcut_tet))[0],1],color="red",lw=linew)
plt.plot(0.001*tet_dist_nochol_10[np.where((tet_dist_nochol_10[:,1]>lowcut_tet) & (tet_dist_nochol_10[:,1]<highcut_tet))[0],0],tet_dist_nochol_10[np.where((tet_dist_nochol_10[:,1]>lowcut_tet) & (tet_dist_nochol_10[:,1]<highcut_tet))[0],1],color="red",lw=linew)
plt.tick_params(axis='both', which='both', labelsize=32, length=6, width=4)
#plt.legend(fontsize=32)
plt.xlabel("Time (ns)",fontsize=36)
plt.ylabel("$d_{tet-tet}$ (nm)",fontsize=36)
plt.xlim(0, 1000)
#plt.ylim(6.7, 6.95)
plt.savefig("AQP0_figS2_Tet_dist.png", bbox_inches="tight")

# %%
lowcut_tet=0
highcut_tet=10
plt.figure(figsize=(12,8))
plt.plot(0.001*tet_dist_chol_1[np.where((tet_dist_chol_1[:,1]>lowcut_tet) & (tet_dist_chol_1[:,1]<highcut_tet))[0],0],tet_dist_chol_1[np.where((tet_dist_chol_1[:,1]>lowcut_tet) & (tet_dist_chol_1[:,1]<highcut_tet))[0],1],color="blue",lw=linew,label="Chol")
plt.plot(0.001*tet_dist_chol_2[np.where((tet_dist_chol_2[:,1]>lowcut_tet) & (tet_dist_chol_2[:,1]<highcut_tet))[0],0],tet_dist_chol_2[np.where((tet_dist_chol_2[:,1]>lowcut_tet) & (tet_dist_chol_2[:,1]<highcut_tet))[0],1],color="blue",lw=linew)
plt.plot(0.001*tet_dist_chol_3[np.where((tet_dist_chol_3[:,1]>lowcut_tet) & (tet_dist_chol_3[:,1]<highcut_tet))[0],0],tet_dist_chol_3[np.where((tet_dist_chol_3[:,1]>lowcut_tet) & (tet_dist_chol_3[:,1]<highcut_tet))[0],1],color="blue",lw=linew)
plt.plot(0.001*tet_dist_chol_4[np.where((tet_dist_chol_4[:,1]>lowcut_tet) & (tet_dist_chol_4[:,1]<highcut_tet))[0],0],tet_dist_chol_4[np.where((tet_dist_chol_4[:,1]>lowcut_tet) & (tet_dist_chol_4[:,1]<highcut_tet))[0],1],color="blue",lw=linew)
plt.plot(0.001*tet_dist_chol_5[np.where((tet_dist_chol_5[:,1]>lowcut_tet) & (tet_dist_chol_5[:,1]<highcut_tet))[0],0],tet_dist_chol_5[np.where((tet_dist_chol_5[:,1]>lowcut_tet) & (tet_dist_chol_5[:,1]<highcut_tet))[0],1],color="blue",lw=linew)
plt.plot(0.001*tet_dist_chol_6[np.where((tet_dist_chol_6[:,1]>lowcut_tet) & (tet_dist_chol_6[:,1]<highcut_tet))[0],0],tet_dist_chol_6[np.where((tet_dist_chol_6[:,1]>lowcut_tet) & (tet_dist_chol_6[:,1]<highcut_tet))[0],1],color="blue",lw=linew)
plt.plot(0.001*tet_dist_chol_7[np.where((tet_dist_chol_7[:,1]>lowcut_tet) & (tet_dist_chol_7[:,1]<highcut_tet))[0],0],tet_dist_chol_7[np.where((tet_dist_chol_7[:,1]>lowcut_tet) & (tet_dist_chol_7[:,1]<highcut_tet))[0],1],color="blue",lw=linew)
plt.plot(0.001*tet_dist_chol_8[np.where((tet_dist_chol_8[:,1]>lowcut_tet) & (tet_dist_chol_8[:,1]<highcut_tet))[0],0],tet_dist_chol_8[np.where((tet_dist_chol_8[:,1]>lowcut_tet) & (tet_dist_chol_8[:,1]<highcut_tet))[0],1],color="blue",lw=linew)
plt.plot(0.001*tet_dist_chol_9[np.where((tet_dist_chol_9[:,1]>lowcut_tet) & (tet_dist_chol_9[:,1]<highcut_tet))[0],0],tet_dist_chol_9[np.where((tet_dist_chol_9[:,1]>lowcut_tet) & (tet_dist_chol_9[:,1]<highcut_tet))[0],1],color="blue",lw=linew)
plt.plot(0.001*tet_dist_chol_10[np.where((tet_dist_chol_10[:,1]>lowcut_tet) & (tet_dist_chol_10[:,1]<highcut_tet))[0],0],tet_dist_chol_10[np.where((tet_dist_chol_10[:,1]>lowcut_tet) & (tet_dist_chol_10[:,1]<highcut_tet))[0],1],color="blue",lw=linew)
plt.plot(0.001*tet_dist_nochol_1[np.where((tet_dist_nochol_1[:,1]>lowcut_tet) & (tet_dist_nochol_1[:,1]<highcut_tet))[0],0],tet_dist_nochol_1[np.where((tet_dist_nochol_1[:,1]>lowcut_tet) & (tet_dist_nochol_1[:,1]<highcut_tet))[0],1],color="red",lw=linew,label="PSM")
plt.plot(0.001*tet_dist_nochol_2[np.where((tet_dist_nochol_2[:,1]>lowcut_tet) & (tet_dist_nochol_2[:,1]<highcut_tet))[0],0],tet_dist_nochol_2[np.where((tet_dist_nochol_2[:,1]>lowcut_tet) & (tet_dist_nochol_2[:,1]<highcut_tet))[0],1],color="red",lw=linew)
plt.plot(0.001*tet_dist_nochol_3[np.where((tet_dist_nochol_3[:,1]>lowcut_tet) & (tet_dist_nochol_3[:,1]<highcut_tet))[0],0],tet_dist_nochol_3[np.where((tet_dist_nochol_3[:,1]>lowcut_tet) & (tet_dist_nochol_3[:,1]<highcut_tet))[0],1],color="red",lw=linew)
plt.plot(0.001*tet_dist_nochol_4[np.where((tet_dist_nochol_4[:,1]>lowcut_tet) & (tet_dist_nochol_4[:,1]<highcut_tet))[0],0],tet_dist_nochol_4[np.where((tet_dist_nochol_4[:,1]>lowcut_tet) & (tet_dist_nochol_4[:,1]<highcut_tet))[0],1],color="red",lw=linew)
plt.plot(0.001*tet_dist_nochol_5[np.where((tet_dist_nochol_5[:,1]>lowcut_tet) & (tet_dist_nochol_5[:,1]<highcut_tet))[0],0],tet_dist_nochol_5[np.where((tet_dist_nochol_5[:,1]>lowcut_tet) & (tet_dist_nochol_5[:,1]<highcut_tet))[0],1],color="red",lw=linew)
plt.plot(0.001*tet_dist_nochol_6[np.where((tet_dist_nochol_6[:,1]>lowcut_tet) & (tet_dist_nochol_6[:,1]<highcut_tet))[0],0],tet_dist_nochol_6[np.where((tet_dist_nochol_6[:,1]>lowcut_tet) & (tet_dist_nochol_6[:,1]<highcut_tet))[0],1],color="red",lw=linew)
plt.plot(0.001*tet_dist_nochol_7[np.where((tet_dist_nochol_7[:,1]>lowcut_tet) & (tet_dist_nochol_7[:,1]<highcut_tet))[0],0],tet_dist_nochol_7[np.where((tet_dist_nochol_7[:,1]>lowcut_tet) & (tet_dist_nochol_7[:,1]<highcut_tet))[0],1],color="red",lw=linew)
plt.plot(0.001*tet_dist_nochol_8[np.where((tet_dist_nochol_8[:,1]>lowcut_tet) & (tet_dist_nochol_8[:,1]<highcut_tet))[0],0],tet_dist_nochol_8[np.where((tet_dist_nochol_8[:,1]>lowcut_tet) & (tet_dist_nochol_8[:,1]<highcut_tet))[0],1],color="red",lw=linew)
plt.plot(0.001*tet_dist_nochol_9[np.where((tet_dist_nochol_9[:,1]>lowcut_tet) & (tet_dist_nochol_9[:,1]<highcut_tet))[0],0],tet_dist_nochol_9[np.where((tet_dist_nochol_9[:,1]>lowcut_tet) & (tet_dist_nochol_9[:,1]<highcut_tet))[0],1],color="red",lw=linew)
plt.plot(0.001*tet_dist_nochol_10[np.where((tet_dist_nochol_10[:,1]>lowcut_tet) & (tet_dist_nochol_10[:,1]<highcut_tet))[0],0],tet_dist_nochol_10[np.where((tet_dist_nochol_10[:,1]>lowcut_tet) & (tet_dist_nochol_10[:,1]<highcut_tet))[0],1],color="red",lw=linew)
plt.tick_params(axis='both', which='both', labelsize=32, length=6, width=4)
#plt.legend(fontsize=32)
plt.xlabel("Time (ns)",fontsize=36)
plt.ylabel("$d_{tet-tet}$ (nm)",fontsize=36)
plt.xlim(0, 1000)
#plt.ylim(6.7, 6.95)
plt.savefig("AQP0_figS2_Tet_dist_hist.png", bbox_inches="tight")

# %%
plt.figure(figsize=(12,8))

plt.scatter(0.001*tet_dist_chol_1[:,0],tet_dist_chol_1[:,1],color="blue",lw=linew,label="Chol")
plt.scatter(0.001*tet_dist_chol_2[:,0],tet_dist_chol_2[:,1],color="blue")
plt.scatter(0.001*tet_dist_chol_3[:,0],tet_dist_chol_3[:,1],color="blue")
plt.scatter(0.001*tet_dist_chol_4[:,0],tet_dist_chol_4[:,1],color="blue")
plt.scatter(0.001*tet_dist_chol_5[:,0],tet_dist_chol_5[:,1],color="blue")
plt.scatter(0.001*tet_dist_chol_6[:,0],tet_dist_chol_6[:,1],color="blue")
plt.scatter(0.001*tet_dist_chol_7[:,0],tet_dist_chol_7[:,1],color="blue")
plt.scatter(0.001*tet_dist_chol_8[:,0],tet_dist_chol_8[:,1],color="blue")
plt.scatter(0.001*tet_dist_chol_9[:,0],tet_dist_chol_9[:,1],color="blue")
plt.scatter(0.001*tet_dist_chol_10[:,0],tet_dist_chol_10[:,1],color="blue")
plt.scatter(0.001*tet_dist_nochol_1[:,0],tet_dist_nochol_1[:,1],color="red",lw=linew,label="PSM")
plt.scatter(0.001*tet_dist_nochol_2[:,0],tet_dist_nochol_2[:,1],color="red")
plt.scatter(0.001*tet_dist_nochol_3[:,0],tet_dist_nochol_3[:,1],color="red")
plt.scatter(0.001*tet_dist_nochol_4[:,0],tet_dist_nochol_4[:,1],color="red")
plt.scatter(0.001*tet_dist_nochol_5[:,0],tet_dist_nochol_5[:,1],color="red")
plt.scatter(0.001*tet_dist_nochol_6[:,0],tet_dist_nochol_6[:,1],color="red")
plt.scatter(0.001*tet_dist_nochol_7[:,0],tet_dist_nochol_7[:,1],color="red")
plt.scatter(0.001*tet_dist_nochol_8[:,0],tet_dist_nochol_8[:,1],color="red")
plt.scatter(0.001*tet_dist_nochol_9[:,0],tet_dist_nochol_9[:,1],color="red")
plt.scatter(0.001*tet_dist_nochol_10[:,0],tet_dist_nochol_10[:,1],color="red")


plt.tick_params(axis='both', which='both', labelsize=32, length=6, width=4)
plt.legend(fontsize=32)
plt.xlabel("Time (ns)",fontsize=36)
plt.ylabel("$d_{Tet-Tet}$ (nm)",fontsize=36)
plt.xlim(0, 1000)
#plt.ylim(6.9,7.1)
#plt.ylim(6.9,6.95)
plt.savefig("AQP0_figS2_Tet_dist_saltos.png", bbox_inches="tight")

# %%
plt.figure(figsize=(12,8))


plt.scatter(0.001*cont_chol_1[:,0],cont_chol_1[:,1],color="blue",lw=linew,label="Chol")
plt.scatter(0.001*cont_chol_2[:,0],cont_chol_2[:,1],color="blue")
plt.scatter(0.001*cont_chol_3[:,0],cont_chol_3[:,1],color="blue")
plt.scatter(0.001*cont_chol_4[:,0],cont_chol_4[:,1],color="blue")
plt.scatter(0.001*cont_chol_5[:,0],cont_chol_5[:,1],color="blue")
plt.scatter(0.001*cont_chol_6[:,0],cont_chol_6[:,1],color="blue")
plt.scatter(0.001*cont_chol_7[:,0],cont_chol_7[:,1],color="blue")
plt.scatter(0.001*cont_chol_8[:,0],cont_chol_8[:,1],color="blue")
plt.scatter(0.001*cont_chol_9[:,0],cont_chol_9[:,1],color="blue")
plt.scatter(0.001*cont_chol_10[:,0],cont_chol_10[:,1],color="blue")
plt.scatter(0.001*cont_nochol_1[:,0],cont_nochol_1[:,1],color="red",lw=linew,label="PSM")
plt.scatter(0.001*cont_nochol_2[:,0],cont_nochol_2[:,1],color="red")
plt.scatter(0.001*cont_nochol_3[:,0],cont_nochol_3[:,1],color="red")
plt.scatter(0.001*cont_nochol_4[:,0],cont_nochol_4[:,1],color="red")
plt.scatter(0.001*cont_nochol_5[:,0],cont_nochol_5[:,1],color="red")
plt.scatter(0.001*cont_nochol_6[:,0],cont_nochol_6[:,1],color="red")
plt.scatter(0.001*cont_nochol_7[:,0],cont_nochol_7[:,1],color="red")
plt.scatter(0.001*cont_nochol_8[:,0],cont_nochol_8[:,1],color="red")
plt.scatter(0.001*cont_nochol_9[:,0],cont_nochol_9[:,1],color="red")
plt.scatter(0.001*cont_nochol_10[:,0],cont_nochol_10[:,1],color="red")



plt.tick_params(axis='both', which='both', labelsize=32, length=6, width=4)
plt.legend(fontsize=32)
plt.xlabel("Time (ns)",fontsize=36)
plt.ylabel("$Contacts_{Tet-Tet}$",fontsize=36)
plt.xlim(0, 1000)
#plt.ylim(6.9,7.1)
#plt.ylim(6.9,6.95)
plt.savefig("AQP0_figS2_cont_saltos.png", bbox_inches="tight")

# %%
plt.figure(figsize=(12,8))


plt.plot(0.001*cont_chol_1[:,0],cont_chol_1[:,1],color="blue",lw=linew,label="Chol")
plt.plot(0.001*cont_chol_2[:,0],cont_chol_2[:,1],color="blue",lw=linew)
plt.plot(0.001*cont_chol_3[:,0],cont_chol_3[:,1],color="blue",lw=linew)
plt.plot(0.001*cont_chol_4[:,0],cont_chol_4[:,1],color="blue",lw=linew)
plt.plot(0.001*cont_chol_5[:,0],cont_chol_5[:,1],color="blue",lw=linew)
plt.plot(0.001*cont_chol_6[:,0],cont_chol_6[:,1],color="blue",lw=linew)
plt.plot(0.001*cont_chol_7[:,0],cont_chol_7[:,1],color="blue",lw=linew)
plt.plot(0.001*cont_chol_8[:,0],cont_chol_8[:,1],color="blue",lw=linew)
plt.plot(0.001*cont_chol_9[:,0],cont_chol_9[:,1],color="blue",lw=linew)
plt.plot(0.001*cont_chol_10[:,0],cont_chol_10[:,1],color="blue",lw=linew)
plt.plot(0.001*cont_nochol_1[:,0],cont_nochol_1[:,1],color="red",lw=linew,label="PSM")
plt.plot(0.001*cont_nochol_2[:,0],cont_nochol_2[:,1],color="red",lw=linew)
plt.plot(0.001*cont_nochol_3[:,0],cont_nochol_3[:,1],color="red",lw=linew)
plt.plot(0.001*cont_nochol_4[:,0],cont_nochol_4[:,1],color="red",lw=linew)
plt.plot(0.001*cont_nochol_5[:,0],cont_nochol_5[:,1],color="red",lw=linew)
plt.plot(0.001*cont_nochol_6[:,0],cont_nochol_6[:,1],color="red",lw=linew)
plt.plot(0.001*cont_nochol_7[:,0],cont_nochol_7[:,1],color="red",lw=linew)
plt.plot(0.001*cont_nochol_8[:,0],cont_nochol_8[:,1],color="red",lw=linew)
plt.plot(0.001*cont_nochol_9[:,0],cont_nochol_9[:,1],color="red",lw=linew)
plt.plot(0.001*cont_nochol_10[:,0],cont_nochol_10[:,1],color="red",lw=linew)



plt.tick_params(axis='both', which='both', labelsize=32, length=6, width=4)
plt.legend(fontsize=32,loc='right', bbox_to_anchor=(1.31, 0.5))
plt.xlabel("Time (ns)",fontsize=36)
plt.ylabel("$\# Contacts_{Tet-Tet}$",fontsize=36)
plt.xlim(0, 1000)
#plt.ylim(6.9,7.1)
#plt.ylim(6.9,6.95)
plt.savefig("AQP0_figS2_cont_label.png", bbox_inches="tight")

# %%
plt.figure(figsize=(12,8))

plt.hist(np.concatenate((cont_chol_1[3000:,1],cont_chol_2[3000:,1],cont_chol_3[3000:,1],cont_chol_4[3000:,1],cont_chol_5[3000:,1],cont_chol_6[3000:,1],cont_chol_7[3000:,1],cont_chol_8[3000:,1],cont_chol_9[3000:,1],cont_chol_10[3000:,1])),bins=25,color="blue",label="Chol",density=True,histtype="step",lw=5)
plt.hist(np.concatenate((cont_nochol_1[3000:,1],cont_nochol_2[3000:,1],cont_nochol_3[3000:,1],cont_nochol_4[3000:,1],cont_nochol_5[3000:,1],cont_nochol_6[3000:,1],cont_nochol_7[3000:,1],cont_nochol_8[3000:,1],cont_nochol_9[3000:,1],cont_nochol_10[3000:,1])),bins=25,color="red",label="SM",density=True,histtype="step",lw=5)

plt.tick_params(axis='both', which='both', labelsize=32, length=6, width=4)
plt.legend(fontsize=32,loc='right', bbox_to_anchor=(1.31, 0.5))
plt.xlabel("$\# Contacts_{Tet-Tet}$",fontsize=36)
plt.ylabel("Probability density (A.U.)",fontsize=36)
plt.savefig("AQP0_figS2_cont_hist.png", bbox_inches="tight")

# %%
np.max(np.concatenate((cont_chol_1[3000:,1],cont_chol_2[3000:,1],cont_chol_3[3000:,1],cont_chol_4[3000:,1],cont_chol_5[3000:,1],cont_chol_6[3000:,1],cont_chol_7[3000:,1],cont_chol_8[3000:,1],cont_chol_9[3000:,1],cont_chol_10[3000:,1])))
# Out:
# 207.0

# %%
plt.figure(figsize=(12,8))

plt.hist(np.concatenate((cont_fix_chol_1[3000:,1],cont_fix_chol_2[3000:,1],cont_fix_chol_3[3000:,1],cont_fix_chol_4[3000:,1],cont_fix_chol_5[3000:,1],cont_fix_chol_6[3000:,1],cont_fix_chol_7[3000:,1],cont_fix_chol_8[3000:,1],cont_fix_chol_9[3000:,1],cont_fix_chol_10[3000:,1])),bins=25,color="blue",label="Chol",density=True,histtype="step",lw=5)
plt.hist(np.concatenate((cont_fix_nochol_1[3000:,1],cont_fix_nochol_2[3000:,1],cont_fix_nochol_3[3000:,1],cont_fix_nochol_4[3000:,1],cont_fix_nochol_5[3000:,1],cont_fix_nochol_6[3000:,1],cont_fix_nochol_7[3000:,1],cont_fix_nochol_8[3000:,1],cont_fix_nochol_9[3000:,1],cont_fix_nochol_10[3000:,1])),bins=25,color="lime",label="SM",density=True,histtype="step",lw=5)

plt.tick_params(axis='both', which='both', labelsize=32, length=6, width=4)
plt.legend(fontsize=32,loc='right', bbox_to_anchor=(1.31, 0.5))
plt.xlabel("$\# Contacts_{Tet-Tet}$",fontsize=36)
plt.ylabel("Probability density (A.U.)",fontsize=36)
plt.savefig("AQP0_figS2_cont_fix_hist.png", bbox_inches="tight")

# %%
plt.figure(figsize=(12,8))
plt.scatter(0.001*CoM_dist_fix_chol_1[:,0],CoM_dist_fix_chol_1[:,1],color="blue",lw=linew,label="Chol.")
plt.scatter(0.001*CoM_dist_fix_chol_2[:,0],CoM_dist_fix_chol_2[:,1],color="blue")
plt.scatter(0.001*CoM_dist_fix_chol_3[:,0],CoM_dist_fix_chol_3[:,1],color="blue")
plt.scatter(0.001*CoM_dist_fix_chol_4[:,0],CoM_dist_fix_chol_4[:,1],color="blue")
plt.scatter(0.001*CoM_dist_fix_chol_5[:,0],CoM_dist_fix_chol_5[:,1],color="blue")
plt.scatter(0.001*CoM_dist_fix_chol_6[:,0],CoM_dist_fix_chol_6[:,1],color="blue")
plt.scatter(0.001*CoM_dist_fix_chol_7[:,0],CoM_dist_fix_chol_7[:,1],color="blue")
plt.scatter(0.001*CoM_dist_fix_chol_8[:,0],CoM_dist_fix_chol_8[:,1],color="blue")
plt.scatter(0.001*CoM_dist_fix_chol_9[:,0],CoM_dist_fix_chol_9[:,1],color="blue")
plt.scatter(0.001*CoM_dist_fix_chol_10[:,0],CoM_dist_fix_chol_10[:,1],color="blue")
plt.scatter(0.001*CoM_dist_fix_nochol_1[:,0],CoM_dist_fix_nochol_1[:,1],color="red",lw=linew,label="PSM")
plt.scatter(0.001*CoM_dist_fix_nochol_2[:,0],CoM_dist_fix_nochol_2[:,1],color="red")
plt.scatter(0.001*CoM_dist_fix_nochol_3[:,0],CoM_dist_fix_nochol_3[:,1],color="red")
plt.scatter(0.001*CoM_dist_fix_nochol_4[:,0],CoM_dist_fix_nochol_4[:,1],color="red")
plt.scatter(0.001*CoM_dist_fix_nochol_5[:,0],CoM_dist_fix_nochol_5[:,1],color="red")
plt.scatter(0.001*CoM_dist_fix_nochol_6[:,0],CoM_dist_fix_nochol_6[:,1],color="red")
plt.scatter(0.001*CoM_dist_fix_nochol_7[:,0],CoM_dist_fix_nochol_7[:,1],color="red")
plt.scatter(0.001*CoM_dist_fix_nochol_8[:,0],CoM_dist_fix_nochol_8[:,1],color="red")
plt.scatter(0.001*CoM_dist_fix_nochol_9[:,0],CoM_dist_fix_nochol_9[:,1],color="red")
plt.scatter(0.001*CoM_dist_fix_nochol_10[:,0],CoM_dist_fix_nochol_10[:,1],color="red")
plt.tick_params(axis='both', which='both', labelsize=32, length=6, width=4)
plt.legend(fontsize=32)
plt.xlabel("Time (ns)",fontsize=36)
plt.ylabel("$d_{CM}$ (nm)",fontsize=36)
#plt.xlim(900, 1000)
#plt.ylim(6.9,7.1)
#plt.ylim(6.9,6.95)
plt.savefig("AQP0_figS2_CMdist_saltos_fix.png", bbox_inches="tight")
# Out:
# <ipython-input-13-8b3e8ac0839f>:29: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   plt.savefig("AQP0_figS2_CMdist_saltos_fix.png", bbox_inches="tight")

# %%
plt.figure(figsize=(12,8))
plt.plot(0.001*CoM_dist_fix_chol_1[:,0],CoM_dist_fix_chol_1[:,1],color="blue",lw=linew,label="Chol")
plt.plot(0.001*CoM_dist_fix_chol_2[:,0],CoM_dist_fix_chol_2[:,1],color="blue",lw=linew)
plt.plot(0.001*CoM_dist_fix_chol_3[:,0],CoM_dist_fix_chol_3[:,1],color="blue",lw=linew)
plt.plot(0.001*CoM_dist_fix_chol_4[:,0],CoM_dist_fix_chol_4[:,1],color="blue",lw=linew)
plt.plot(0.001*CoM_dist_fix_chol_5[:,0],CoM_dist_fix_chol_5[:,1],color="blue",lw=linew)
plt.plot(0.001*CoM_dist_fix_chol_6[:,0],CoM_dist_fix_chol_6[:,1],color="blue",lw=linew)
plt.plot(0.001*CoM_dist_fix_chol_7[:,0],CoM_dist_fix_chol_7[:,1],color="blue",lw=linew)
plt.plot(0.001*CoM_dist_fix_chol_8[:,0],CoM_dist_fix_chol_8[:,1],color="blue",lw=linew)
plt.plot(0.001*CoM_dist_fix_chol_9[:,0],CoM_dist_fix_chol_9[:,1],color="blue",lw=linew)
plt.plot(0.001*CoM_dist_fix_chol_10[:,0],CoM_dist_fix_chol_10[:,1],color="blue",lw=linew)
plt.plot(0.001*CoM_dist_fix_nochol_1[:,0],CoM_dist_fix_nochol_1[:,1],color="lime",lw=linew,label="SM")
plt.plot(0.001*CoM_dist_fix_nochol_2[:,0],CoM_dist_fix_nochol_2[:,1],color="lime",lw=linew)
plt.plot(0.001*CoM_dist_fix_nochol_3[:,0],CoM_dist_fix_nochol_3[:,1],color="lime",lw=linew)
plt.plot(0.001*CoM_dist_fix_nochol_4[:,0],CoM_dist_fix_nochol_4[:,1],color="lime",lw=linew)
plt.plot(0.001*CoM_dist_fix_nochol_5[:,0],CoM_dist_fix_nochol_5[:,1],color="lime",lw=linew)
plt.plot(0.001*CoM_dist_fix_nochol_6[:,0],CoM_dist_fix_nochol_6[:,1],color="lime",lw=linew)
plt.plot(0.001*CoM_dist_fix_nochol_7[:,0],CoM_dist_fix_nochol_7[:,1],color="lime",lw=linew)
plt.plot(0.001*CoM_dist_fix_nochol_8[:,0],CoM_dist_fix_nochol_8[:,1],color="lime",lw=linew)
plt.plot(0.001*CoM_dist_fix_nochol_9[:,0],CoM_dist_fix_nochol_9[:,1],color="lime",lw=linew)
plt.plot(0.001*CoM_dist_fix_nochol_10[:,0],CoM_dist_fix_nochol_10[:,1],color="lime",lw=linew)
plt.tick_params(axis='both', which='both', labelsize=32, length=6, width=4)
plt.legend(fontsize=32)
plt.xlabel("Time (ns)",fontsize=36)
plt.ylabel("$d_{CM}$ (nm)",fontsize=36)
plt.xlim(0, 1000)
plt.savefig("AQP0_figS2_CMdist_fix.png", bbox_inches="tight")

# %%
plt.figure(figsize=(12,8))

plt.plot(0.001*tet_dist_fix_chol_1[:,0],tet_dist_fix_chol_1[:,1],color="blue",lw=linew,label="Chol")
plt.plot(0.001*tet_dist_fix_chol_2[:,0],tet_dist_fix_chol_2[:,1],color="blue",lw=linew)
plt.plot(0.001*tet_dist_fix_chol_3[:,0],tet_dist_fix_chol_3[:,1],color="blue",lw=linew)
plt.plot(0.001*tet_dist_fix_chol_4[:,0],tet_dist_fix_chol_4[:,1],color="blue",lw=linew)
plt.plot(0.001*tet_dist_fix_chol_5[:,0],tet_dist_fix_chol_5[:,1],color="blue",lw=linew)
plt.plot(0.001*tet_dist_fix_chol_6[:,0],tet_dist_fix_chol_6[:,1],color="blue",lw=linew)
plt.plot(0.001*tet_dist_fix_chol_7[:,0],tet_dist_fix_chol_7[:,1],color="blue",lw=linew)
plt.plot(0.001*tet_dist_fix_chol_8[:,0],tet_dist_fix_chol_8[:,1],color="blue",lw=linew)
plt.plot(0.001*tet_dist_fix_chol_9[:,0],tet_dist_fix_chol_9[:,1],color="blue",lw=linew)
plt.plot(0.001*tet_dist_fix_chol_10[:,0],tet_dist_fix_chol_10[:,1],color="blue",lw=linew)
plt.plot(0.001*tet_dist_fix_nochol_1[:,0],tet_dist_fix_nochol_1[:,1],color="lime",lw=linew,label="SM")
plt.plot(0.001*tet_dist_fix_nochol_2[:,0],tet_dist_fix_nochol_2[:,1],color="lime",lw=linew)
plt.plot(0.001*tet_dist_fix_nochol_3[:,0],tet_dist_fix_nochol_3[:,1],color="lime",lw=linew)
plt.plot(0.001*tet_dist_fix_nochol_4[:,0],tet_dist_fix_nochol_4[:,1],color="lime",lw=linew)
plt.plot(0.001*tet_dist_fix_nochol_5[:,0],tet_dist_fix_nochol_5[:,1],color="lime",lw=linew)
plt.plot(0.001*tet_dist_fix_nochol_6[:,0],tet_dist_fix_nochol_6[:,1],color="lime",lw=linew)
plt.plot(0.001*tet_dist_fix_nochol_7[:,0],tet_dist_fix_nochol_7[:,1],color="lime",lw=linew)
plt.plot(0.001*tet_dist_fix_nochol_8[:,0],tet_dist_fix_nochol_8[:,1],color="lime",lw=linew)
plt.plot(0.001*tet_dist_fix_nochol_9[:,0],tet_dist_fix_nochol_9[:,1],color="lime",lw=linew)
plt.plot(0.001*tet_dist_fix_nochol_10[:,0],tet_dist_fix_nochol_10[:,1],color="lime",lw=linew)

plt.tick_params(axis='both', which='both', labelsize=32, length=6, width=4)

plt.xlabel("Time (ns)",fontsize=36)
plt.ylabel("$d_{tet-tet}$ (nm)",fontsize=36)
plt.xlim(0, 1000)

plt.savefig("AQP0_figS2_Tet_dist_fix.png", bbox_inches="tight")
