# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
from scipy import stats

mpl.rcParams['axes.linewidth'] = 3.5 #set the value globally
linew=0.1

# %%
# mptg-cbp or juan
chol_conan_1 = pd.read_csv('/home/juan/prueba_remota/production_servidor/temporal_servidor_production/two-tet-expand/chol/1/aggregate/timeline.dat', delim_whitespace=True, skip_blank_lines=True, header=None,skiprows=3,usecols=[4])
chol_conan_2 = pd.read_csv('/home/juan/prueba_remota/production_servidor/temporal_servidor_production/two-tet-expand/chol/2/aggregate/timeline.dat', delim_whitespace=True, skip_blank_lines=True, header=None,skiprows=3,usecols=[4])
chol_conan_3 = pd.read_csv('/home/juan/prueba_remota/production_servidor/temporal_servidor_production/two-tet-expand/chol/3/aggregate/timeline.dat', delim_whitespace=True, skip_blank_lines=True, header=None,skiprows=3,usecols=[4])
chol_conan_4 = pd.read_csv('/home/juan/prueba_remota/production_servidor/temporal_servidor_production/two-tet-expand/chol/4/aggregate/timeline.dat', delim_whitespace=True, skip_blank_lines=True, header=None,skiprows=3,usecols=[4])
chol_conan_5 = pd.read_csv('/home/juan/prueba_remota/production_servidor/temporal_servidor_production/two-tet-expand/chol/5/aggregate/timeline.dat', delim_whitespace=True, skip_blank_lines=True, header=None,skiprows=3,usecols=[4])
chol_conan_6 = pd.read_csv('/home/juan/prueba_remota/production_servidor/temporal_servidor_production/two-tet-expand/chol/6/aggregate/timeline.dat', delim_whitespace=True, skip_blank_lines=True, header=None,skiprows=3,usecols=[4])
chol_conan_7 = pd.read_csv('/home/juan/prueba_remota/production_servidor/temporal_servidor_production/two-tet-expand/chol/7/aggregate/timeline.dat', delim_whitespace=True, skip_blank_lines=True, header=None,skiprows=3,usecols=[4])
chol_conan_8 = pd.read_csv('/home/juan/prueba_remota/production_servidor/temporal_servidor_production/two-tet-expand/chol/8/aggregate/timeline.dat', delim_whitespace=True, skip_blank_lines=True, header=None,skiprows=3,usecols=[4])
chol_conan_9 = pd.read_csv('/home/juan/prueba_remota/production_servidor/temporal_servidor_production/two-tet-expand/chol/9/aggregate/timeline.dat', delim_whitespace=True, skip_blank_lines=True, header=None,skiprows=3,usecols=[4])
chol_conan_10 = pd.read_csv('/home/juan/prueba_remota/production_servidor/temporal_servidor_production/two-tet-expand/chol/10/aggregate/timeline.dat', delim_whitespace=True, skip_blank_lines=True, header=None,skiprows=3,usecols=[4])

# %%
no_chol_conan_1 = pd.read_csv('/home/juan/prueba_remota/production_servidor/temporal_servidor_production/two-tet-expand/no_chol/1/aggregate/timeline.dat', delim_whitespace=True, skip_blank_lines=True, header=None,skiprows=3,usecols=[4])
no_chol_conan_2 = pd.read_csv('/home/juan/prueba_remota/production_servidor/temporal_servidor_production/two-tet-expand/no_chol/2/aggregate/timeline.dat', delim_whitespace=True, skip_blank_lines=True, header=None,skiprows=3,usecols=[4])
no_chol_conan_3 = pd.read_csv('/home/juan/prueba_remota/production_servidor/temporal_servidor_production/two-tet-expand/no_chol/3/aggregate/timeline.dat', delim_whitespace=True, skip_blank_lines=True, header=None,skiprows=3,usecols=[4])
no_chol_conan_4 = pd.read_csv('/home/juan/prueba_remota/production_servidor/temporal_servidor_production/two-tet-expand/no_chol/4/aggregate/timeline.dat', delim_whitespace=True, skip_blank_lines=True, header=None,skiprows=3,usecols=[4])
no_chol_conan_5 = pd.read_csv('/home/juan/prueba_remota/production_servidor/temporal_servidor_production/two-tet-expand/no_chol/5/aggregate/timeline.dat', delim_whitespace=True, skip_blank_lines=True, header=None,skiprows=3,usecols=[4])
no_chol_conan_6 = pd.read_csv('/home/juan/prueba_remota/production_servidor/temporal_servidor_production/two-tet-expand/no_chol/6/aggregate/timeline.dat', delim_whitespace=True, skip_blank_lines=True, header=None,skiprows=3,usecols=[4])
no_chol_conan_7 = pd.read_csv('/home/juan/prueba_remota/production_servidor/temporal_servidor_production/two-tet-expand/no_chol/7/aggregate/timeline.dat', delim_whitespace=True, skip_blank_lines=True, header=None,skiprows=3,usecols=[4])
no_chol_conan_8 = pd.read_csv('/home/juan/prueba_remota/production_servidor/temporal_servidor_production/two-tet-expand/no_chol/8/aggregate/timeline.dat', delim_whitespace=True, skip_blank_lines=True, header=None,skiprows=3,usecols=[4])
no_chol_conan_9 = pd.read_csv('/home/juan/prueba_remota/production_servidor/temporal_servidor_production/two-tet-expand/no_chol/9/aggregate/timeline.dat', delim_whitespace=True, skip_blank_lines=True, header=None,skiprows=3,usecols=[4])
no_chol_conan_10 = pd.read_csv('/home/juan/prueba_remota/production_servidor/temporal_servidor_production/two-tet-expand/no_chol/10/aggregate/timeline.dat', delim_whitespace=True, skip_blank_lines=True, header=None,skiprows=3,usecols=[4])

# %%
chol_conan_agg=0.1*((chol_conan_1+chol_conan_2+chol_conan_3+chol_conan_4+chol_conan_5+chol_conan_6+chol_conan_7+chol_conan_8+chol_conan_9+chol_conan_10).to_numpy().reshape((1752,1752)))
no_chol_conan_agg=0.1*((no_chol_conan_1+no_chol_conan_2+no_chol_conan_3+no_chol_conan_4+no_chol_conan_5+no_chol_conan_6+no_chol_conan_7+no_chol_conan_8+no_chol_conan_9+no_chol_conan_10).to_numpy().reshape((1752,1752)))

# %%
plt.figure(figsize=(16,16))
plt.imshow(chol_conan_agg.clip(0,0.1), cmap='inferno_r', interpolation='none')
plt.colorbar()
plt.show()
plt.figure(figsize=(16,16))
plt.imshow(no_chol_conan_agg.clip(0,0.1), cmap='inferno_r', interpolation='none')
plt.colorbar()
plt.show()

# %%
plt.figure(figsize=(16,16))
plt.imshow(chol_conan_agg[876:,0:876].clip(0,0.1), cmap='inferno_r', interpolation='none')
plt.colorbar()
plt.show()
plt.figure(figsize=(16,16))
plt.imshow(no_chol_conan_agg[876:,0:876].clip(0,0.1), cmap='inferno_r', interpolation='none')
plt.colorbar()
plt.show()

# %%
chol_conan=(chol_conan_1+chol_conan_2+chol_conan_3+chol_conan_4+chol_conan_5+chol_conan_6+chol_conan_7+chol_conan_8+chol_conan_9+chol_conan_10)
no_chol_conan=(no_chol_conan_1+no_chol_conan_2+no_chol_conan_3+no_chol_conan_4+no_chol_conan_5+no_chol_conan_6+no_chol_conan_7+no_chol_conan_8+no_chol_conan_9+no_chol_conan_10)

# %%
chol_conan.iloc[876*876:876*876*2][chol_conan.iloc[876*876:876*876*2][4]>1]
# Out:
#                  4
# 767814   10.000000
# 767815   10.000000
# 767816    6.398086
# 767817    5.036423
# 767818    5.180546
# ...            ...
# 1533871   7.293957
# 1533872   4.375660
# 1533873   6.896444
# 1533874  10.000000
# 1533875  10.000000
#
# [6042 rows x 1 columns]

# %%
np.transpose((chol_conan_agg[876:,0:876]>0.1).nonzero())     # np.asarray(my_array>10).nonzero()
#np.transpose((no_chol_conan_agg[876:,0:876]>0.1).nonzero())     # np.asarray(my_array>10).nonzero()
# Out:
# array([[223, 868],
#        [223, 872],
#        [308, 861],
#        [318, 779],
#        [319, 780],
#        [319, 783],
#        [326, 777],
#        [409, 853],
#        [561, 100],
#        [634, 190],
#        [649,   8],
#        [649, 872],
#        [653, 872]])

# %%
print(np.floor_divide(np.transpose((chol_conan_agg[0:876,876:]>0.1).nonzero()),219)+[1,1])  # tetramers, make sense
print(np.floor_divide(np.transpose((no_chol_conan_agg[0:876,876:]>0.1).nonzero()),219)+[1,1])
# Out:
# [[1 3]
#  [1 3]
#  [1 3]
#  [4 2]
#  [4 2]
#  [4 2]
#  [4 2]
#  [4 2]
#  [4 2]
#  [4 2]
#  [4 2]
#  [4 3]
#  [4 3]]
# [[1 3]
#  [1 3]
#  [1 3]
#  [1 3]
#  [1 3]
#  [1 3]
#  [4 2]
#  [4 2]
#  [4 2]
#  [4 2]
#  [4 3]
#  [4 3]]

# %%
print(np.remainder(np.transpose((chol_conan_agg[0:876,876:]>0.1).nonzero()),219)+[6,6])  # residues, consistent w previous resutls
print(np.remainder(np.transpose((no_chol_conan_agg[0:876,876:]>0.1).nonzero()),219)+[6,6])  # residues, consistent w previous resutls
# Out:
# [[ 14 217]
#  [106 129]
#  [196 202]
#  [126 113]
#  [128 105]
#  [129 106]
#  [132 106]
#  [202 196]
#  [210  95]
#  [217  10]
#  [221  10]
#  [221 217]
#  [221 221]]
# [[ 10  77]
#  [ 10 217]
#  [ 11 221]
#  [ 14 217]
#  [ 95 210]
#  [196 202]
#  [202 196]
#  [210  95]
#  [217  10]
#  [217  14]
#  [221 221]
#  [221 222]]

# %%
print([(224-5)*1,(224-5)*2,(224-5)*3,(224-5)*4,(224-5)*5,(224-5)*6,(224-5)*7,(224-5)*8])  # separators for monomers
# Out:
# [219, 438, 657, 876, 1095, 1314, 1533, 1752]

# %%
#chol_conan_agg[223+876, 868]
a,b=(np.transpose((chol_conan_agg[876:,0:876]>0.1).nonzero())+[876,0]).tolist()[0]
chol_conan_agg[a,b]
# Out:
# 0.30337100000000006

# %%
for a,b in (np.transpose((chol_conan_agg[876:,0:876]>0.1).nonzero())+[876,0]).tolist() :
    print(chol_conan_agg[a,b])
print("\n")
for a,b in (np.transpose((no_chol_conan_agg[876:,0:876]>0.1).nonzero())+[876,0]).tolist() :
    print(no_chol_conan_agg[a,b])
# Out:
# 0.30337100000000006
# 0.1256819
# 0.1260819
# 0.1493213
# 0.20111400000000001
# 0.1080131
# 0.12592480000000003
# 0.255192
# 0.1869018
# 0.17211830000000003
# 0.11024120000000003
# 0.13756610000000002
# 0.34172270000000005
#
#
# 0.39143000000000006
# 0.22045410000000004
# 0.2160834
# 0.31608340000000007
# 0.11109849999999999
# 0.1441365
# 0.2212539
# 0.14042280000000001
# 0.21985430000000006
# 0.12412500000000003
# 0.41942580000000007
# 0.1024568

# %% [markdown]
# array([[ 14, 217],
#        [106, 129],
#        [196, 202],
#        [126, 113],
#        [128, 105],
#        [129, 106],
#        [132, 106],
#        [202, 196],
#        [210,  95],
#        [217,  10],
#        [221,  10],
#        [221, 217],
#        [221, 221]])
#
# array([[ 10,  77],
#        [ 10, 217],
#        [ 11, 221],
#        [ 14, 217],
#        [ 95, 210],
#        [196, 202],
#        [202, 196],
#        [210,  95],
#        [217,  10],
#        [217,  14],
#        [221, 221],
#        [221, 222]])
#
# [[1 3]
#  [1 3]
#  [1 3]
#  [4 2]
#  [4 2]
#  [4 2]
#  [4 2]
#  [4 2]
#  [4 2]
#  [4 2]
#  [4 2]
#  [4 3]
#  [4 3]]
# [[1 3]
#  [1 3]
#  [1 3]
#  [1 3]
#  [1 3]
#  [1 3]
#  [4 2]
#  [4 2]
#  [4 2]
#  [4 2]
#  [4 3]
#  [4 3]]
#
#
# son equivalentes en chol y no_chol respectivamente a:  *(los que tienen su propia invertida)
#
# Phe14,Leu217  = 30.3
# Ser106,Gln129 = 12.6 **
# Arg196,Trp202 = 12.6 **
# SER126,ARG113 = 14.9
# GLY128,TYR105 = 20.1
# Gln129,Ser106 = 10.8 **
# ILE132,Ser106 = 12.6
# Trp202,Arg196 = 25.5 **
# Ile210,Leu95  = 18.7
# Leu217,Trp10  = 17.2
# Phe221,Trp10  = 11.0
# Phe221,Leu217 = 13.8 **** no deberia tener invertida
# Phe221,Phe221 = 34.2 **** su propio espejo, no puede tener invertida
#
# Trp10, Val77  = 39.1
# Trp10,Leu217  = 22.0 **
# ARG11,Phe221  = 21.6
# Phe14,Leu217  = 31.6 **
# Leu95,Ile210  = 11.1 **
# Arg196,Trp202 = 14.4 **
# Trp202,Arg196 = 22.1 **
# Ile210,Leu95  = 14.0 **
# Leu217,Trp10  = 22.0 **
# Leu217,Phe14  = 12.4 **
# Phe221,Phe221 = 41.9 **** su propio espejo, no puede tener invertida
# Phe221,LEU222 = 10.2 **** no deberia tener invertida
#
# o, ordenados:  *(los que tienen en comun)
#
# Phe221,Phe221 = 34.2  *
# Phe14,Leu217  = 30.3  *
# Trp202,Arg196 = 25.5  *
# GLY128,TYR105 = 20.1
# Ile210,Leu95  = 18.7  *
# Leu217,Trp10  = 17.2  *
# SER126,ARG113 = 14.9
# Phe221,Leu217 = 13.8
# Ser106,Gln129 = 12.6
# Arg196,Trp202 = 12.6
# ILE132,Ser106 = 12.6
# Phe221,Trp10  = 11.0
# Gln129,Ser106 = 10.8
#
# Phe221,Phe221 = 41.9  *
# Trp10, Val77  = 39.1
# Phe14,Leu217  = 31.6  *
# ARG11,Phe221  = 21.6
# Trp202,Arg196 = 22.1  *
# Trp10,Leu217  = 22.0  *  *inverted
# Leu217,Trp10  = 22.0  *
# Arg196,Trp202 = 14.4
# Ile210,Leu95  = 14.0  *
# Leu217,Phe14  = 12.4  *  *inverted
# Leu95,Ile210  = 11.1  *  *inverted
# Phe221,LEU222 = 10.2
#
#
# Do I need to symmetrysize(sp?)?

# %%
np.remainder(np.transpose((chol_conan_agg[876:,0:876]+chol_conan_agg[0:876,876:]>0.2).nonzero()),219)+[6,6]

#np.remainder(np.transpose((chol_conan_agg[0:876,876:]>0.1).nonzero()),219)+[6,6]
#aqui filas son iguales a: 0 y 6, 1 y 4, 2 y 5, 3 y 7
# Out:
# array([[ 10, 217],
#        [106, 129],
#        [196, 202],
#        [221, 221],
#        [129, 106],
#        [202, 196],
#        [217,  10],
#        [221, 221]])

# %%
for a,b in (np.transpose((chol_conan_agg[876:,0:876]+chol_conan_agg[0:876,876:]>0.2).nonzero())+[876,0]).tolist() :
    print(chol_conan_agg[a,b])
# Out:
# 0.30337100000000006
# 0.20111400000000001
# 0.255192
# 0.34172270000000005
# 0.0
# 0.0
# 0.0
# 0.0

# %%
for a,b in (np.transpose((chol_conan_agg[876:,0:876]>0.1).nonzero())).tolist() :
    print(chol_conan_agg[a+876,b],chol_conan_agg[b,a+876])
# Out:
# 0.30337100000000006 0.30337100000000006
# 0.1256819 0.1256819
# 0.1260819 0.1260819
# 0.1493213 0.1493213
# 0.20111400000000001 0.20111400000000001
# 0.1080131 0.1080131
# 0.12592480000000003 0.12592480000000003
# 0.255192 0.255192
# 0.1869018 0.1869018
# 0.17211830000000003 0.17211830000000003
# 0.11024120000000003 0.11024120000000003
# 0.13756610000000002 0.13756610000000002
# 0.34172270000000005 0.34172270000000005

# %%
#notice how there are no interactions between 1 and 2, only 3 and 4, and the ones that
# can be mirrored, i.e. 1 and 3, and 4 and 2
print(np.floor_divide(np.transpose((chol_conan_agg[0:876,876:]>0.01).nonzero()),219)+[1,1])  # tetramers, make sense
print(np.floor_divide(np.transpose((no_chol_conan_agg[0:876,876:]>0.01).nonzero()),219)+[1,1])
# Out:
# [[1 3]
#  [1 3]
#  [1 3]
#  [1 3]
#  [1 3]
#  [1 3]
#  [1 3]
#  [1 3]
#  [1 3]
#  [1 3]
#  [1 3]
#  [1 3]
#  [1 3]
#  [1 3]
#  [1 3]
#  [1 3]
#  [1 3]
#  [4 2]
#  [4 2]
#  [4 2]
#  [4 2]
#  [4 2]
#  [4 2]
#  [4 2]
#  [4 2]
#  [4 2]
#  [4 3]
#  [4 2]
#  [4 2]
#  [4 2]
#  [4 2]
#  [4 2]
#  [4 2]
#  [4 2]
#  [4 2]
#  [4 3]
#  [4 2]
#  [4 2]
#  [4 2]
#  [4 2]
#  [4 3]
#  [4 3]
#  [4 3]
#  [4 3]
#  [4 3]
#  [4 2]]
# [[1 3]
#  [1 3]
#  [1 3]
#  [1 3]
#  [1 3]
#  [1 3]
#  [1 3]
#  [1 3]
#  [1 3]
#  [1 3]
#  [4 2]
#  [4 2]
#  [4 2]
#  [4 2]
#  [4 2]
#  [4 2]
#  [4 3]
#  [4 2]
#  [4 2]
#  [4 2]
#  [4 3]
#  [4 3]
#  [4 3]
#  [4 3]
#  [4 2]
#  [4 3]]

# %%
print(chol_conan_agg[0:876,876:].sum())
print(no_chol_conan_agg[0:876,876:].sum())
#mas contactos en total para chol: si se multiplica eso por 700 se obtendria el numero de 
# ns en contacto*residuo
# Out:
# 3.7856039
# 3.4552797000000006

# %% [markdown]
# # Now, what if we check differences

# %%
for a,b in (np.transpose((chol_conan_agg[876:,0:876]>0.1).nonzero())+[876,0]).tolist() :
    print(chol_conan_agg[a,b])
print("\n")
for a,b in (np.transpose((no_chol_conan_agg[876:,0:876]>0.1).nonzero())+[876,0]).tolist() :
    print(no_chol_conan_agg[a,b])
    
print(np.remainder(np.transpose((chol_conan_agg[0:876,876:]>0.1).nonzero()),219)+[6,6])  # residues, consistent w previous resutls
print(np.remainder(np.transpose((no_chol_conan_agg[0:876,876:]>0.1).nonzero()),219)+[6,6])  # residues, consistent w previous resutls
# Out:
# 0.30337100000000006
# 0.1256819
# 0.1260819
# 0.1493213
# 0.20111400000000001
# 0.1080131
# 0.12592480000000003
# 0.255192
# 0.1869018
# 0.17211830000000003
# 0.11024120000000003
# 0.13756610000000002
# 0.34172270000000005
#
#
# 0.39143000000000006
# 0.22045410000000004
# 0.2160834
# 0.31608340000000007
# 0.11109849999999999
# 0.1441365
# 0.2212539
# 0.14042280000000001
# 0.21985430000000006
# 0.12412500000000003
# 0.41942580000000007
# 0.1024568
# [[ 14 217]
#  [106 129]
#  [196 202]
#  [126 113]
#  [128 105]
#  [129 106]
#  [132 106]
#  [202 196]
#  [210  95]
#  [217  10]
#  [221  10]
#  [221 217]
#  [221 221]]
# [[ 10  77]
#  [ 10 217]
#  [ 11 221]
#  [ 14 217]
#  [ 95 210]
#  [196 202]
#  [202 196]
#  [210  95]
#  [217  10]
#  [217  14]
#  [221 221]
#  [221 222]]

# %%
for a,b in (np.transpose((np.absolute((chol_conan_agg-no_chol_conan_agg)[876:,0:876])>0.01).nonzero())+[876,0]).tolist() :
    print(" = "+((chol_conan_agg-no_chol_conan_agg)[a,b]).astype('str'))
# Out:
#  = 0.012969499999999998
#  = -0.0261963
#  = -0.036466099999999994
#  = 0.0130124
#  = 0.011069800000000001
#  = -0.088059
#  = 0.03336660000000001
#  = 0.0158121
#  = -0.14409340000000004
#  = -0.09000150000000001
#  = 0.0544491
#  = 0.07223239999999999
#  = 0.1401796
#  = 0.024825000000000003
#  = 0.043822400000000004
#  = 0.20111400000000001
#  = 0.1080131
#  = 0.12532480000000004
#  = 0.0126697
#  = -0.0314812
#  = -0.060891400000000095
#  = -0.06714749999999998
#  = 0.06633330000000001
#  = 0.090544
#  = 0.046693200000000004
#  = 0.09284379999999999
#  = 0.0224969
#  = 0.1869018
#  = 0.034352099999999997
#  = 0.0425939
#  = 0.042579800000000015
#  = 0.02798180000000003
#  = -0.1241392
#  = -0.0927153
#  = 0.016569100000000003
#  = -0.10961310000000003
#  = 0.04686480000000004
#  = -0.06700470000000001
#  = -0.08258830000000002
#  = -0.0860735
#  = -0.03470920000000002
#  = -0.0128126
#  = -0.07770310000000002
#  = 0.0295241
#  = -0.0305669
#  = -0.057049
# ...

# %%
print(np.remainder(np.transpose((np.absolute((chol_conan_agg-no_chol_conan_agg)[0:876,876:])>0.01).nonzero()),219)+[6,6])  # residues, consistent w previous resutls
# Out:
# [[  6 221]
#  [  7 221]
#  [ 10  77]
#  [ 10 217]
#  [ 10 221]
#  [ 11 217]
#  [ 11 221]
#  [ 11 224]
#  [ 14 217]
#  [ 95 210]
#  [105 126]
#  [105 127]
#  [105 128]
#  [106 128]
#  [106 129]
#  [106 132]
#  [113 126]
#  [196 200]
#  [196 202]
#  [ 77  10]
#  [126 105]
#  [126 113]
#  [127 105]
#  [128 105]
#  [128 106]
#  [129 105]
#  [129 106]
#  [129 113]
#  [129 129]
#  [132 106]
#  [200 196]
#  [202 196]
#  [210  95]
#  [213  10]
#  [214  10]
#  [217  10]
#  [217  14]
#  [217 221]
#  [221   7]
#  [221  10]
#  [221  11]
#  [221 217]
#  [221 221]
#  [221 222]
#  [222 221]
#  [224   7]
#  [224 221]]

# %% [markdown]
# Ser6,Phe221 = 0.012969499999999998
# Ala7,Phe221 = -0.0261963
# Trp10,Val77 = -0.036466099999999994
# Trp10,Leu217 = 0.0130124
# Trp10,Phe221 = 0.011069800000000001
# Arg11,Leu217 = -0.088059
# Arg11,Phe221 = 0.03336660000000001
# Arg11,Phe224 = 0.0158121
# Phe14,Leu217 = -0.14409340000000004
# Leu95,Ile210 = -0.09000150000000001
# Tyr105,Ser126 = 0.0544491
# Tyr105,Val127 = 0.07223239999999999
# Tyr105,Gly128 = 0.1401796
# Ser106,Gly128 = 0.024825000000000003
# Ser106,Gln129 = 0.043822400000000004
# Ser106,Ile132 = 0.20111400000000001
# Arg113,Ser126 = 0.1080131
# Arg196,Asn200 = 0.12532480000000004
# Arg196,Trp202 = 0.0126697
# Val77,Trp10 = -0.0314812
# Ser126,Tyr105 = -0.060891400000000095
# Ser126,Arg113 = -0.06714749999999998
# Val127,Tyr105 = 0.06633330000000001
# Gly128,Tyr105 = 0.090544
# Gly128,Ser106 = 0.046693200000000004
# Gln129,Tyr105 = 0.09284379999999999
# Gln129,Ser106 = 0.0224969
# Gln129,Arg113 = 0.1869018
# Gln129,Gln129 = 0.034352099999999997
# Ile132,Ser106 = 0.0425939
# Asn200,Arg196 = 0.042579800000000015
# Trp202,Arg196 = 0.02798180000000003
# Ile210,Leu95 = -0.1241392
# Gly213,Trp10 = -0.0927153
# Leu214,Trp10 = 0.016569100000000003
# Leu217,Trp10 = -0.10961310000000003
# Leu217,Phe14 = 0.04686480000000004
# Leu217,Phe221 = -0.06700470000000001
# Phe221,Ala7 = -0.08258830000000002
# Phe221,Trp10 = -0.0860735
# Phe221,Arg11 = -0.03470920000000002
# Phe221,Leu217 = -0.0128126
# Phe221,Phe221 = -0.07770310000000002
# Phe221,Leu222 = 0.0295241
# Leu222,Phe221 = -0.0305669
# Phe224,Ala7 = -0.057049
# Phe224,Phe221 = -0.011669800000000001

# %%
chol_conan_agg.shape
# Out:
# (1752, 1752)

# %% [markdown]
# # Podemos tratar de usar la simetria

# %%
for a,b in (np.transpose((chol_conan_agg[876:,0:876]>0.1).nonzero())+[876,0]).tolist() :
    print(chol_conan_agg[a,b])
print("\n")
for a,b in (np.transpose((no_chol_conan_agg[876:,0:876]>0.1).nonzero())+[876,0]).tolist() :
    print(no_chol_conan_agg[a,b])
    
print(np.remainder(np.transpose((chol_conan_agg[0:876,876:]>0.1).nonzero()),219)+[6,6])  # residues, consistent w previous resutls
print(np.remainder(np.transpose((no_chol_conan_agg[0:876,876:]>0.1).nonzero()),219)+[6,6])  # residues, consistent w previous resutls
# Out:
# 0.30337100000000006
# 0.1256819
# 0.1260819
# 0.1493213
# 0.20111400000000001
# 0.1080131
# 0.12592480000000003
# 0.255192
# 0.1869018
# 0.17211830000000003
# 0.11024120000000003
# 0.13756610000000002
# 0.34172270000000005
#
#
# 0.39143000000000006
# 0.22045410000000004
# 0.2160834
# 0.31608340000000007
# 0.11109849999999999
# 0.1441365
# 0.2212539
# 0.14042280000000001
# 0.21985430000000006
# 0.12412500000000003
# 0.41942580000000007
# 0.1024568
# [[ 14 217]
#  [106 129]
#  [196 202]
#  [126 113]
#  [128 105]
#  [129 106]
#  [132 106]
#  [202 196]
#  [210  95]
#  [217  10]
#  [221  10]
#  [221 217]
#  [221 221]]
# [[ 10  77]
#  [ 10 217]
#  [ 11 221]
#  [ 14 217]
#  [ 95 210]
#  [196 202]
#  [202 196]
#  [210  95]
#  [217  10]
#  [217  14]
#  [221 221]
#  [221 222]]

# %%
for a,b in (np.transpose((chol_conan_agg[0:218,1314:1532]>0.1).nonzero())+[0,1314]).tolist() :
    print(chol_conan_agg[a,b])
for a,b in (np.transpose((chol_conan_agg[1314:1532,0:218]>0.1).nonzero())+[1314,0]).tolist() :
    print(chol_conan_agg[a,b])
np.transpose((no_chol_conan_agg[876:,0:876]>0.1).nonzero())
# Out:
# 0.11024120000000003
# 0.1869018
# 0.17211830000000003
# 0.1869018
# 0.17211830000000003
# 0.11024120000000003
# array([[223, 868],
#        [227, 868],
#        [308, 861],
#        [409, 853],
#        [509,   4],
#        [634, 190],
#        [642,  89],
#        [649,   4],
#        [649,   8],
#        [653,   5],
#        [653, 872],
#        [654, 872]])

# %%
print(np.remainder(np.transpose((chol_conan_agg[1314:1532,0:218]>0.1).nonzero()),219)+[6,6]) 
print(np.remainder(np.transpose((chol_conan_agg[0:218,1314:1532]>0.1).nonzero()),219)+[6,6])
# Out:
# [[129 106]
#  [202 196]
#  [217  14]]
# [[ 14 217]
#  [106 129]
#  [196 202]]

# %%
for a,b in (np.transpose((chol_conan_agg[657:875,1095:1313]>0.1).nonzero())+[657,1095]).tolist() :
    print(chol_conan_agg[a,b])
# Out:
# 0.12592480000000003
# 0.1493213
# 0.20111400000000001
# 0.1080131
# 0.255192
# 0.1260819
# 0.30337100000000006
# 0.1256819

# %%
print(np.remainder(np.transpose((chol_conan_agg[657:875,1095:1313]>0.1).nonzero()),219)+[6,6])
# Out:
# [[126 113]
#  [128 105]
#  [129 106]
#  [132 106]
#  [202 196]
#  [210  95]
#  [217  10]
#  [221  10]]

# %%
for a,b in (np.transpose((chol_conan_agg[0:218,1095:1313]>0.1).nonzero())+[0,1095]).tolist() :  #None as expected
    print(chol_conan_agg[a,b])

# %%
for a,b in (np.transpose((chol_conan_agg[657:875,1314:1532]>0.1).nonzero())+[657,1314]).tolist() :
    print(chol_conan_agg[a,b])
print("\n")
for a,b in (np.transpose((no_chol_conan_agg[657:875,1314:1532]>0.1).nonzero())+[657,1314]).tolist() :
    print(no_chol_conan_agg[a,b])
# Out:
# 0.13756610000000002
# 0.34172270000000005
#
#
# 0.41942580000000007
# 0.1024568

# %%
print(np.remainder(np.transpose((chol_conan_agg[657:875,1314:1532]>0.1).nonzero()),219)+[6,6])
print(np.remainder(np.transpose((no_chol_conan_agg[657:875,1314:1532]>0.1).nonzero()),219)+[6,6])
# Out:
# [[221 217]
#  [221 221]]
# [[221 221]
#  [221 222]]

# %%
for a,b in (np.transpose((chol_conan_agg[657:875,1095:1313]>0.1).nonzero())+[657,1095]).tolist() :
    print(chol_conan_agg[a,b])
for a,b in (np.transpose((chol_conan_agg[0:218,1314:1532]>0.1).nonzero())+[0,1314]).tolist() :
    print(chol_conan_agg[a,b])
# Out:
# 0.12592480000000003
# 0.1493213
# 0.20111400000000001
# 0.1080131
# 0.255192
# 0.1260819
# 0.30337100000000006
# 0.1256819
# 0.11024120000000003
# 0.1869018
# 0.17211830000000003

# %%
chol_symm=0.5*(chol_conan_agg[0:218,1314:1532]+chol_conan_agg[657:875,1095:1313])
for a,b in (np.transpose((chol_symm>0.1).nonzero())).tolist() :
    print(chol_symm[a,b])
# Out:
# 0.10055700000000001
# 0.127596
# 0.15168550000000003

# %%
no_chol_symm=0.5*(no_chol_conan_agg[0:218,1314:1532]+no_chol_conan_agg[657:875,1095:1313])
for a,b in (np.transpose((no_chol_symm>0.1).nonzero())).tolist() :
    print(no_chol_symm[a,b])
# Out:
# 0.10992715000000003
# 0.11062695
# 0.15804170000000003
# 0.1080417
# 0.19571500000000003
# 0.11022705000000002

# %%
print(np.remainder(np.transpose((chol_symm>0.1).nonzero()),219)+[6,6])
# Out:
# [[129 106]
#  [202 196]
#  [217  10]]

# %%
print(np.remainder(np.transpose((no_chol_symm>0.1).nonzero()),219)+[6,6])
# Out:
# [[ 14 217]
#  [ 95 210]
#  [202 196]
#  [210  95]
#  [217  10]
#  [217  14]]

# %%
chol_symm.shape
# Out:
# (218, 218)

# %% [markdown]
# # Sanity check
#
# aca estamos probando Ser106-Ile132

# %%
#pd.read_csv('/home/juan/prueba_remota/production_servidor/temporal_servidor_production/two-tet-expand/chol/1/aggregate/timeline.dat', delim_whitespace=True, skip_blank_lines=True, header=None,skiprows=3,usecols=[4])
sancheck_chol_101_1441=pd.read_csv('sanity_check/chol/101_1441.xvg', delim_whitespace=True, header=None,usecols=[1])
sancheck_chol_1196_784=pd.read_csv('sanity_check/chol/1196_784.xvg', delim_whitespace=True, header=None,usecols=[1])
sancheck_nochol_101_1441=pd.read_csv('sanity_check/no_chol/101_1441.xvg', delim_whitespace=True, header=None,usecols=[1])
sancheck_nochol_1196_784=pd.read_csv('sanity_check/no_chol/1196_784.xvg', delim_whitespace=True, header=None,usecols=[1])

# %%
#print("Values bigger than 10 =", x[x>10])
#print("Their indices are ", np.nonzero(x > 10))

#fractions in contact are, for chol and then no_chol
print(np.count_nonzero(sancheck_chol_101_1441<0.35)/70010)
print(np.count_nonzero(sancheck_chol_1196_784<0.35)/70010)
print(np.count_nonzero(sancheck_nochol_101_1441<0.35)/70010)
print(np.count_nonzero(sancheck_nochol_1196_784<0.35)/70010)
# Out:
# 0.04249392943865162
# 0.10777031852592486
# 0.0
# 0.0

# %%
print(chol_conan_agg[219*6+132-6,106-6])  # ile in 7th monomer w ser in 1st
print(chol_conan_agg[106-6,219*6+132-6])
print(chol_conan_agg[219*5+106-6,219*3+132-6])  # ile in 4th monomer w ser in 6th
print(chol_conan_agg[219*3+132-6,219*5+106-6])
print("\n")
print(no_chol_conan_agg[219*6+132-6,106-6])  # ile in 7th monomer w ser in 1st
print(no_chol_conan_agg[106-6,219*6+132-6])
print(no_chol_conan_agg[219*5+106-6,219*3+132-6])  # ile in 4th monomer w ser in 6th
print(no_chol_conan_agg[219*3+132-6,219*5+106-6])
# Out:
# 0.0425939
# 0.0425939
# 0.1080131
# 0.1080131
#
#
# 0.0
# 0.0
# 0.0
# 0.0

# %%
for a,b in (np.transpose((chol_conan_agg==0.1080131).nonzero())).tolist() :
    print(chol_conan_agg[a,b])
# Out:
# 0.1080131
# 0.1080131

# %%
#print(np.remainder(np.transpose((chol_conan_agg[]==0.1080131).nonzero()),219)+[6,6])

# %%
print(np.remainder(np.transpose((chol_conan_agg[0:876,876:]>0.1).nonzero()),219)+[6,6])  # residues, consistent w previous resutls
for a,b in (np.transpose((chol_conan_agg[0:876,876:]>0.1).nonzero())+[0,876]).tolist() :
    print(chol_conan_agg[a,b])
# Out:
# [[ 14 217]
#  [106 129]
#  [196 202]
#  [126 113]
#  [128 105]
#  [129 106]
#  [132 106]
#  [202 196]
#  [210  95]
#  [217  10]
#  [221  10]
#  [221 217]
#  [221 221]]
# 0.11024120000000003
# 0.1869018
# 0.17211830000000003
# 0.12592480000000003
# 0.1493213
# 0.20111400000000001
# 0.1080131
# 0.255192
# 0.1260819
# 0.30337100000000006
# 0.1256819
# 0.13756610000000002
# 0.34172270000000005

# %%
for a,b in (np.transpose((chol_conan_agg[0:876,876:]>0.1).nonzero())+[0,876]).tolist() :
    print(np.remainder([a,b],219)+[6,6])
    print(chol_conan_agg[a,b])
# Out:
# [ 14 217]
# 0.11024120000000003
# [106 129]
# 0.1869018
# [196 202]
# 0.17211830000000003
# [126 113]
# 0.12592480000000003
# [128 105]
# 0.1493213
# [129 106]
# 0.20111400000000001
# [132 106]
# 0.1080131
# [202 196]
# 0.255192
# [210  95]
# 0.1260819
# [217  10]
# 0.30337100000000006
# [221  10]
# 0.1256819
# [221 217]
# 0.13756610000000002
# [221 221]
# 0.34172270000000005

# %%
for a,b in (np.transpose((np.absolute((chol_conan_agg-no_chol_conan_agg)[0:876,876:])>0.01).nonzero())+[0,876]).tolist() :
    print(np.remainder([a,b],219)+[6,6])
    print((chol_conan_agg-no_chol_conan_agg)[a,b])
# Out:
# [  6 221]
# -0.06700470000000001
# [  7 221]
# -0.08258830000000002
# [10 77]
# -0.06714749999999998
# [ 10 217]
# -0.0927153
# [ 10 221]
# -0.0860735
# [ 11 217]
# 0.016569100000000003
# [ 11 221]
# -0.03470920000000002
# [ 11 224]
# -0.011669800000000001
# [ 14 217]
# -0.10961310000000003
# [ 95 210]
# -0.1241392
# [105 126]
# 0.06633330000000001
# [105 127]
# 0.046693200000000004
# [105 128]
# 0.09284379999999999
# [106 128]
# 0.0224969
# [106 129]
# 0.1869018
# [106 132]
# 0.0425939
# [113 126]
# 0.090544
# [196 200]
# 0.042579800000000015
# [196 202]
# 0.02798180000000003
# [77 10]
# -0.036466099999999994
# [126 105]
# 0.0544491
# [126 113]
# 0.12532480000000004
# [127 105]
# 0.07223239999999999
# [128 105]
# 0.1401796
# [128 106]
# 0.043822400000000004
# [129 105]
# 0.024825000000000003
# [129 106]
# 0.20111400000000001
# [129 113]
# 0.0126697
# [129 129]
# 0.034352099999999997
# [132 106]
# 0.1080131
# [200 196]
# -0.0314812
# [202 196]
# -0.060891400000000095
# [210  95]
# ...

# %% [markdown]
# Ser6,Phe221 = -0.06700470000000001
# Ala7,Phe221 = -0.08258830000000002
# Trp10,Val77 = -0.06714749999999998
# Trp10,Leu217 = -0.0927153
# Trp10,Phe221 = -0.0860735
# Arg11,Leu217 = 0.016569100000000003
# Arg11,Phe221 = -0.03470920000000002
# Arg11,Phe224 = -0.011669800000000001
# Phe14,Leu217 = -0.10961310000000003
# Leu95,Ile210 = -0.1241392
# Tyr105,Ser126 = 0.06633330000000001
# Tyr105,Val127 = 0.046693200000000004
# Tyr105,Gly128 = 0.09284379999999999
# Ser106,Gly128 = 0.0224969
# Ser106,Gln129 = 0.1869018
# Ser106,Ile132 = 0.0425939
# Arg113,Ser126 = 0.090544
# Arg196,Asn200 = 0.042579800000000015
# Arg196,Trp202 = 0.02798180000000003
# Val77,Trp10 = -0.036466099999999994
# Ser126,Tyr105 = 0.0544491
# Ser126,Arg113 = 0.12532480000000004
# Val127,Tyr105 = 0.07223239999999999
# Gly128,Tyr105 = 0.1401796
# Gly128,Ser106 = 0.043822400000000004
# Gln129,Tyr105 = 0.024825000000000003
# Gln129,Ser106 = 0.20111400000000001
# Gln129,Arg113 = 0.0126697
# Gln129,Gln129 = 0.034352099999999997
# Ile132,Ser106 = 0.1080131
# Asn200,Arg196 = -0.0314812
# Trp202,Arg196 = -0.060891400000000095
# Ile210,Leu95 = -0.09000150000000001
# Gly213,Trp10 = 0.0130124
# Leu214,Trp10 = 0.011069800000000001
# Leu217,Trp10 = -0.088059
# Leu217,Phe14 = -0.14409340000000004
# Leu217,Phe221 = -0.0128126
# Phe221,Ala7 = 0.012969499999999998
# Phe221,Trp10 = 0.03336660000000001
# Phe221,Arg11 = 0.0158121
# Phe221,Leu217 = 0.04686480000000004
# Phe221,Phe221 = -0.07770310000000002
# Phe221,Leu222 = -0.057049
# Leu222,Phe221 = 0.0295241
# Phe224,Ala7 = -0.0261963
# Phe224,Phe221 = -0.0305669

# %%
for a,b in (np.transpose((no_chol_conan_agg[0:876,876:]>0.1).nonzero())+[0,876]).tolist() :
    print(np.remainder([a,b],219)+[6,6])
    print(no_chol_conan_agg[a,b])
# Out:
# [10 77]
# 0.11109849999999999
# [ 10 217]
# 0.14042280000000001
# [ 11 221]
# 0.12412500000000003
# [ 14 217]
# 0.21985430000000006
# [ 95 210]
# 0.2212539
# [196 202]
# 0.1441365
# [202 196]
# 0.31608340000000007
# [210  95]
# 0.2160834
# [217  10]
# 0.39143000000000006
# [217  14]
# 0.22045410000000004
# [221 221]
# 0.41942580000000007
# [221 222]
# 0.1024568

# %% [markdown]
# ## more sanity checks

# %%
print(chol_conan_agg[219*6+129-6,106-6])  # ile in 7th monomer w ser in 1st
print(chol_conan_agg[106-6,219*6+129-6])
print(chol_conan_agg[219*5+106-6,219*3+129-6])  # ile in 4th monomer w ser in 6th
print(chol_conan_agg[219*3+129-6,219*5+106-6])
print("\n")
print(no_chol_conan_agg[219*6+129-6,106-6])  # ile in 7th monomer w ser in 1st
print(no_chol_conan_agg[106-6,219*6+129-6])
print(no_chol_conan_agg[219*5+106-6,219*3+129-6])  # ile in 4th monomer w ser in 6th
print(no_chol_conan_agg[219*3+129-6,219*5+106-6])
# Out:
# 0.1869018
# 0.1869018
# 0.20111400000000001
# 0.20111400000000001
#
#
# 0.0
# 0.0
# 0.0
# 0.0

# %%
print(chol_conan_agg[219*6+217-6,14-6])  # ile in 7th monomer w ser in 1st
print(chol_conan_agg[14-6,219*6+217-6])
print(chol_conan_agg[219*5+14-6,219*3+217-6])  # ile in 4th monomer w ser in 6th
print(chol_conan_agg[219*3+217-6,219*5+14-6])
print("\n")
print(no_chol_conan_agg[219*6+217-6,14-6])  # ile in 7th monomer w ser in 1st
print(no_chol_conan_agg[14-6,219*6+217-6])
print(no_chol_conan_agg[219*5+14-6,219*3+217-6])  # ile in 4th monomer w ser in 6th
print(no_chol_conan_agg[219*3+217-6,219*5+14-6])
# Out:
# 0.11024120000000003
# 0.11024120000000003
# 0.0763607
# 0.0763607
#
#
# 0.21985430000000006
# 0.21985430000000006
# 0.22045410000000004
# 0.22045410000000004

# %%
print(0.0763607-0.22045410000000004)
# Out:
# -0.14409340000000004

# %% [markdown]
# ## podriamos simetrizar?

# %%
symme_chol=0.5*(chol_conan_agg[219*6:219*7,0:219]+np.transpose(chol_conan_agg[219*5:219*6,219*3:219*4]))
symme_no_chol=0.5*(no_chol_conan_agg[219*6:219*7,0:219]+np.transpose(no_chol_conan_agg[219*5:219*6,219*3:219*4]))
no_symme_chol=0.5*(chol_conan_agg[219*6:219*7,219*3:219*4]+np.transpose(chol_conan_agg[219*6:219*7,219*3:219*4]) )  #or [219*6:219*7,219*3:219*4]  [219*5:219*6,0:219]
no_symme_no_chol=0.5*(no_chol_conan_agg[219*6:219*7,219*3:219*4]+np.transpose(no_chol_conan_agg[219*6:219*7,219*3:219*4]))

# %%
#0.0425939
#0.1080131
for a,b in (np.transpose((symme_chol>0.05).nonzero())).tolist() :
    print(np.array([a,b])+[6,6])
    print(symme_chol[a,b])
# Out:
# [126 105]
# 0.062469550000000006
# [126 113]
# 0.10832015000000002
# [127 105]
# 0.05968435
# [128 105]
# 0.12384645
# [129 106]
# 0.1940079
# [132 106]
# 0.0753035
# [202 196]
# 0.21365515000000002
# [210  95]
# 0.1115983
# [217  10]
# 0.17553925000000004
# [217  14]
# 0.09330095000000002
# [221  10]
# 0.06576905000000001
# [221  11]
# 0.0636195

# %%
for a,b in (np.transpose((np.absolute((symme_chol-symme_no_chol))>0.01).nonzero())).tolist() :
    print(np.remainder([a,b],219)+[6,6])
    print((symme_chol-symme_no_chol)[a,b])
# Out:
# [77 10]
# -0.0518068
# [126 105]
# 0.060391200000000006
# [126 113]
# 0.10793440000000001
# [127 105]
# 0.059462799999999996
# [128 105]
# 0.1165117
# [128 106]
# 0.03315965
# [129 105]
# 0.015247850000000002
# [129 106]
# 0.1940079
# [132 106]
# 0.0753035
# [202 196]
# -0.01645480000000002
# [210  95]
# -0.10707035000000002
# [217  10]
# -0.09038714999999997
# [217  14]
# -0.12685325000000003
# [221   6]
# -0.033266750000000005
# [221   7]
# -0.03480940000000001
# [221  10]
# -0.026353449999999987
# [224   7]
# -0.01309815

# %%
for a,b in (np.transpose((np.absolute((chol_conan_agg-no_chol_conan_agg)[219*6:219*7,219*3:219*4])>0.0001).nonzero())+[219*6,219*3]).tolist() :
    #print([a,b])
    print(np.remainder([a,b],219)+[6,6])
    print((chol_conan_agg-no_chol_conan_agg)[a,b])
# Out:
# [129 129]
# 0.034352099999999997
# [217 221]
# 0.04686480000000004
# [217 222]
# 0.0023998000000000005
# [218 221]
# 0.0015997000000000001
# [221 217]
# -0.0128126
# [221 221]
# -0.07770310000000002
# [221 222]
# 0.0295241
# [221 223]
# -0.0001428
# [221 224]
# -0.0305669
# [222 217]
# -0.0037567000000000004
# [222 221]
# -0.057049
# [222 222]
# -0.0013284000000000002
# [224 221]
# -0.0024568
# [224 224]
# -0.0041852

# %%
print(chol_conan_agg[219*6+129-6,106-6])  # ile in 7th monomer w ser in 1st
print(chol_conan_agg[219*5+106-6,219*3+129-6])  # ile in 4th monomer w ser in 6th

print("\n")
print(no_chol_conan_agg[219*6+129-6,106-6])  # ile in 7th monomer w ser in 1st
print(no_chol_conan_agg[219*5+106-6,219*3+129-6])  # ile in 4th monomer w ser in 6th
# Out:
# 0.1869018
# 0.20111400000000001
#
#
# 0.0
# 0.0

# %%
# %%bash
# grep CA prot_cent.pdb | head -n219 | awk '{print $6 "\t" $4 "\t" $7 "\t" $8 "\t" $9}' > residues.txt

# %%
residue_names=pd.read_csv('residues.txt', delimiter="\t", header=None,index_col=0)
prueba=residue_names.loc[[6]].values[0][0]
#residue_names.loc[[6]].values[0][3]

# %%
chol_conan_agg_sem=stats.sem(np.concatenate((chol_conan_1,chol_conan_2,chol_conan_3,chol_conan_4,chol_conan_5,chol_conan_6,chol_conan_7,chol_conan_8,chol_conan_9,chol_conan_10),axis=1),axis=1).reshape((1752,1752))
no_chol_conan_agg_sem=stats.sem(np.concatenate((no_chol_conan_1,no_chol_conan_2,no_chol_conan_3,no_chol_conan_4,no_chol_conan_5,no_chol_conan_6,no_chol_conan_7,no_chol_conan_8,no_chol_conan_9,no_chol_conan_10),axis=1),axis=1).reshape((1752,1752))

#symme_chol_sem=0.5*np.sqrt(chol_conan_agg_sem[219*6:219*7,0:219]**2+np.transpose(chol_conan_agg_sem[219*5:219*6,219*3:219*4])**2+2*chol_conan_agg_sem[219*6:219*7,0:219]*np.transpose(chol_conan_agg_sem[219*5:219*6,219*3:219*4]))
#symme_no_chol_sem=0.5*np.sqrt(no_chol_conan_agg_sem[219*6:219*7,0:219]**2+np.transpose(no_chol_conan_agg_sem[219*5:219*6,219*3:219*4])**2+2*no_chol_conan_agg_sem[219*6:219*7,0:219]*np.transpose(no_chol_conan_agg_sem[219*5:219*6,219*3:219*4]))
#no_symme_chol_sem=0.5*np.sqrt(chol_conan_agg_sem[219*6:219*7,219*3:219*4]**2+np.transpose(chol_conan_agg_sem[219*6:219*7,219*3:219*4])**2+2*chol_conan_agg_sem[219*6:219*7,219*3:219*4]*np.transpose(chol_conan_agg_sem[219*6:219*7,219*3:219*4]) )  
#no_symme_no_chol_sem=0.5*np.sqrt(no_chol_conan_agg_sem[219*6:219*7,219*3:219*4]**2+np.transpose(no_chol_conan_agg_sem[219*6:219*7,219*3:219*4])**2+2*no_chol_conan_agg_sem[219*6:219*7,219*3:219*4]*np.transpose(no_chol_conan_agg_sem[219*6:219*7,219*3:219*4]) )  
symme_chol_sem=0.5*np.sqrt(chol_conan_agg_sem[219*6:219*7,0:219]**2+np.transpose(chol_conan_agg_sem[219*5:219*6,219*3:219*4])**2)
symme_no_chol_sem=0.5*np.sqrt(no_chol_conan_agg_sem[219*6:219*7,0:219]**2+np.transpose(no_chol_conan_agg_sem[219*5:219*6,219*3:219*4])**2)
no_symme_chol_sem=0.5*np.sqrt(chol_conan_agg_sem[219*6:219*7,219*3:219*4]**2+np.transpose(chol_conan_agg_sem[219*6:219*7,219*3:219*4])**2)  
no_symme_no_chol_sem=0.5*np.sqrt(no_chol_conan_agg_sem[219*6:219*7,219*3:219*4]**2+np.transpose(no_chol_conan_agg_sem[219*6:219*7,219*3:219*4])**2)

# %%
! rm symme_automatic.txt
for a,b in (np.transpose((np.absolute((symme_chol-symme_no_chol))>0.01).nonzero())).tolist() :
    resid1, resid2=np.remainder([a,b],219)+[6,6]
    value=(symme_chol-symme_no_chol)[a,b]
    #value_sem=(100*0.5*np.sqrt(symme_chol_sem**2+symme_no_chol_sem**2-2*symme_chol_sem*symme_no_chol_sem))[a,b]
    value_sem=(0.5*np.sqrt(symme_chol_sem**2+symme_no_chol_sem**2))[a,b]
    v_chol=symme_chol[a,b]
    v_chol_sem=symme_chol_sem[a,b]
    v_no_chol=symme_no_chol[a,b]
    v_no_chol_sem=symme_no_chol_sem[a,b]
    res1_name=residue_names.loc[[resid1]].values[0][0]
    res2_name=residue_names.loc[[resid2]].values[0][0]
    x=residue_names.loc[[resid1]].values[0][1]
    y=residue_names.loc[[resid1]].values[0][2]
    z=residue_names.loc[[resid1]].values[0][3]
    if y>90 or x<80:
        if z>45:
            color="grey"  # freed so we might use instead of black
        else:
            color="white"  #not grey anymore
    else:
        color="white"
    #print('{}{}\t{}{}\t= {}'.format(res1_name,resid1,res2_name,resid2,value))
    with open('symme_automatic.txt', 'a') as f:
        f.write('{}{}\t{}{}\t{}\t{}\t{}\t{}\t{}\t{}\t{}\t{}\t{}\t{}\n'.format(res1_name,resid1,res2_name,resid2,value,v_chol,v_no_chol,color,value_sem,v_chol_sem,v_no_chol_sem,"symme",a,b))

# %%
res = []
[res.append(x) for x in np.sort(np.transpose((np.absolute((no_symme_chol-no_symme_no_chol))>0.01).nonzero())).tolist() if x not in res]
for a,b in res :
    resid1, resid2=np.remainder([a,b],219)+[6,6]
    value=(no_symme_chol-no_symme_no_chol)[a,b]
    #value_sem=(100*0.5*np.sqrt(no_symme_chol_sem**2+no_symme_no_chol_sem**2-2*no_symme_chol_sem*no_symme_no_chol_sem))[a,b]
    value_sem=(0.5*np.sqrt(no_symme_chol_sem**2+no_symme_no_chol_sem**2))[a,b]
    v_chol=no_symme_chol[a,b]
    v_chol_sem=no_symme_chol_sem[a,b]
    v_no_chol=no_symme_no_chol[a,b]
    v_no_chol_sem=no_symme_no_chol_sem[a,b]
    res1_name=residue_names.loc[[resid1]].values[0][0]
    res2_name=residue_names.loc[[resid2]].values[0][0]
    x=residue_names.loc[[resid1]].values[0][1]
    y=residue_names.loc[[resid1]].values[0][2]
    z=residue_names.loc[[resid1]].values[0][3]
    #print(z)
    if y>90 or x<80:
        if z>45:
            color="grey"  # freed so we might use instead of black
        else:
            color="white"  #not grey anymore
    else:
        color="white"
    #print('{}{}\t{}{}\t= {}'.format(res1_name,resid1,res2_name,resid2,value))
    with open('symme_automatic.txt', 'a') as f:
        f.write('{}{}\t{}{}\t{}\t{}\t{}\t{}\t{}\t{}\t{}\t{}\t{}\t{}\n'.format(res1_name,resid1,res2_name,resid2,value,v_chol,v_no_chol,color,value_sem,v_chol_sem,v_no_chol_sem,"nosym",a,b))

# %%
symme_contacts=pd.read_csv('symme_automatic.txt', delimiter="\t", header=None)
#(np.transpose((np.absolute((no_symme_chol-no_symme_no_chol))>0.01).nonzero())).tolist()

# %%
symme_contacts.sort_values(by=2)
# Out:
#         0       1         2         3         4      5         6         7   \
# 12  LEU217   PHE14 -0.126853  0.093301  0.220154  white  0.037764  0.028263
# 10  ILE210   LEU95 -0.107070  0.111598  0.218669  white  0.026155  0.028227
# 11  LEU217   TRP10 -0.090387  0.175539  0.265926  white  0.048687  0.063411
# 19  PHE221  PHE221 -0.077703  0.341723  0.419426  white  0.059549  0.081554
# 0    VAL77   TRP10 -0.051807  0.040030  0.091837  white  0.022432  0.018164
# 14  PHE221    ALA7 -0.034809  0.008906  0.043715  white  0.021336  0.006333
# 13  PHE221    SER6 -0.033267  0.015383  0.048650  white  0.017649  0.007230
# 15  PHE221   TRP10 -0.026353  0.065769  0.092122  white  0.035625  0.034265
# 21  PHE221  PHE224 -0.016512  0.000621  0.017133  white  0.005243  0.000448
# 9   TRP202  ARG196 -0.016455  0.213655  0.230110  white  0.045083  0.065751
# 20  PHE221  LEU222 -0.013762  0.038466  0.052228  white  0.021996  0.014831
# ...

# %%
#symme_contacts.sort_values(by=2)[[0,1]]
#nombres=symme_contacts.sort_values(by=2)[0]+symme_contacts.sort_values(by=2)[1]
nombres=symme_contacts.sort_values(by=2)[[0,1]].agg('-'.join, axis=1)
#nombres
a,b=215,211
print(100*(no_symme_chol-no_symme_no_chol)[a,b])
print(100*no_symme_chol[a,b])
print(100*no_symme_no_chol[a,b])
print(100*(no_symme_chol-no_symme_no_chol)[b,a])
print(100*no_symme_chol[b,a])
print(100*no_symme_no_chol[b,a])
# Out:
# 1.702610000000003
# 7.843165000000002
# 6.140554999999999
# 1.702610000000003
# 7.843165000000002
# 6.140554999999999

# %%
plt.figure(figsize=(16,6))
plt.bar(
    x=np.arange(symme_contacts.shape[0]),
    height=100*symme_contacts.sort_values(by=2)[2],
    tick_label=nombres,
    color=symme_contacts.sort_values(by=2)[5],
    edgecolor="black",
    yerr=100*symme_contacts.sort_values(by=2)[6],
    capsize=5
)
plt.xticks(rotation=70,fontsize=16,horizontalalignment="right")#,position=(-0.9,-0.15),rotation_mode="anchor") #horizontalalignment="right")
plt.yticks(fontsize=24)
plt.xlim(-0.7,21.7)
plt.tick_params(axis='both', which='both', labelsize=32, length=6, width=4)
plt.ylabel(r"$\Delta T_{ij}$ (% points)",fontsize=36)#,loc="top")
plt.savefig("conan_difference_fix.png", bbox_inches="tight")

# %%
chol_nummeet_1 = pd.read_csv('/home/juan/prueba_remota/production_servidor/temporal_servidor_production/two-tet-expand/chol/1/aggregate/timeline.dat', delim_whitespace=True, skip_blank_lines=True, header=None,skiprows=3,usecols=[6])
chol_nummeet_2 = pd.read_csv('/home/juan/prueba_remota/production_servidor/temporal_servidor_production/two-tet-expand/chol/2/aggregate/timeline.dat', delim_whitespace=True, skip_blank_lines=True, header=None,skiprows=3,usecols=[6])
chol_nummeet_3 = pd.read_csv('/home/juan/prueba_remota/production_servidor/temporal_servidor_production/two-tet-expand/chol/3/aggregate/timeline.dat', delim_whitespace=True, skip_blank_lines=True, header=None,skiprows=3,usecols=[6])
chol_nummeet_4 = pd.read_csv('/home/juan/prueba_remota/production_servidor/temporal_servidor_production/two-tet-expand/chol/4/aggregate/timeline.dat', delim_whitespace=True, skip_blank_lines=True, header=None,skiprows=3,usecols=[6])
chol_nummeet_5 = pd.read_csv('/home/juan/prueba_remota/production_servidor/temporal_servidor_production/two-tet-expand/chol/5/aggregate/timeline.dat', delim_whitespace=True, skip_blank_lines=True, header=None,skiprows=3,usecols=[6])
chol_nummeet_6 = pd.read_csv('/home/juan/prueba_remota/production_servidor/temporal_servidor_production/two-tet-expand/chol/6/aggregate/timeline.dat', delim_whitespace=True, skip_blank_lines=True, header=None,skiprows=3,usecols=[6])
chol_nummeet_7 = pd.read_csv('/home/juan/prueba_remota/production_servidor/temporal_servidor_production/two-tet-expand/chol/7/aggregate/timeline.dat', delim_whitespace=True, skip_blank_lines=True, header=None,skiprows=3,usecols=[6])
chol_nummeet_8 = pd.read_csv('/home/juan/prueba_remota/production_servidor/temporal_servidor_production/two-tet-expand/chol/8/aggregate/timeline.dat', delim_whitespace=True, skip_blank_lines=True, header=None,skiprows=3,usecols=[6])
chol_nummeet_9 = pd.read_csv('/home/juan/prueba_remota/production_servidor/temporal_servidor_production/two-tet-expand/chol/9/aggregate/timeline.dat', delim_whitespace=True, skip_blank_lines=True, header=None,skiprows=3,usecols=[6])
chol_nummeet_10 = pd.read_csv('/home/juan/prueba_remota/production_servidor/temporal_servidor_production/two-tet-expand/chol/10/aggregate/timeline.dat', delim_whitespace=True, skip_blank_lines=True, header=None,skiprows=3,usecols=[6])

no_chol_nummeet_1 = pd.read_csv('/home/juan/prueba_remota/production_servidor/temporal_servidor_production/two-tet-expand/no_chol/1/aggregate/timeline.dat', delim_whitespace=True, skip_blank_lines=True, header=None,skiprows=3,usecols=[6])
no_chol_nummeet_2 = pd.read_csv('/home/juan/prueba_remota/production_servidor/temporal_servidor_production/two-tet-expand/no_chol/2/aggregate/timeline.dat', delim_whitespace=True, skip_blank_lines=True, header=None,skiprows=3,usecols=[6])
no_chol_nummeet_3 = pd.read_csv('/home/juan/prueba_remota/production_servidor/temporal_servidor_production/two-tet-expand/no_chol/3/aggregate/timeline.dat', delim_whitespace=True, skip_blank_lines=True, header=None,skiprows=3,usecols=[6])
no_chol_nummeet_4 = pd.read_csv('/home/juan/prueba_remota/production_servidor/temporal_servidor_production/two-tet-expand/no_chol/4/aggregate/timeline.dat', delim_whitespace=True, skip_blank_lines=True, header=None,skiprows=3,usecols=[6])
no_chol_nummeet_5 = pd.read_csv('/home/juan/prueba_remota/production_servidor/temporal_servidor_production/two-tet-expand/no_chol/5/aggregate/timeline.dat', delim_whitespace=True, skip_blank_lines=True, header=None,skiprows=3,usecols=[6])
no_chol_nummeet_6 = pd.read_csv('/home/juan/prueba_remota/production_servidor/temporal_servidor_production/two-tet-expand/no_chol/6/aggregate/timeline.dat', delim_whitespace=True, skip_blank_lines=True, header=None,skiprows=3,usecols=[6])
no_chol_nummeet_7 = pd.read_csv('/home/juan/prueba_remota/production_servidor/temporal_servidor_production/two-tet-expand/no_chol/7/aggregate/timeline.dat', delim_whitespace=True, skip_blank_lines=True, header=None,skiprows=3,usecols=[6])
no_chol_nummeet_8 = pd.read_csv('/home/juan/prueba_remota/production_servidor/temporal_servidor_production/two-tet-expand/no_chol/8/aggregate/timeline.dat', delim_whitespace=True, skip_blank_lines=True, header=None,skiprows=3,usecols=[6])
no_chol_nummeet_9 = pd.read_csv('/home/juan/prueba_remota/production_servidor/temporal_servidor_production/two-tet-expand/no_chol/9/aggregate/timeline.dat', delim_whitespace=True, skip_blank_lines=True, header=None,skiprows=3,usecols=[6])
no_chol_nummeet_10 = pd.read_csv('/home/juan/prueba_remota/production_servidor/temporal_servidor_production/two-tet-expand/no_chol/10/aggregate/timeline.dat', delim_whitespace=True, skip_blank_lines=True, header=None,skiprows=3,usecols=[6])

# %%
chol_meetavg_1=np.divide(chol_conan_1, chol_nummeet_1, out=np.zeros_like(chol_conan_1), where=chol_nummeet_1!=0)
chol_meetavg_2=np.divide(chol_conan_2, chol_nummeet_2, out=np.zeros_like(chol_conan_2), where=chol_nummeet_2!=0)
chol_meetavg_3=np.divide(chol_conan_3, chol_nummeet_3, out=np.zeros_like(chol_conan_3), where=chol_nummeet_3!=0)
chol_meetavg_4=np.divide(chol_conan_4, chol_nummeet_4, out=np.zeros_like(chol_conan_4), where=chol_nummeet_4!=0)
chol_meetavg_5=np.divide(chol_conan_5, chol_nummeet_5, out=np.zeros_like(chol_conan_5), where=chol_nummeet_5!=0)
chol_meetavg_6=np.divide(chol_conan_6, chol_nummeet_6, out=np.zeros_like(chol_conan_6), where=chol_nummeet_6!=0)
chol_meetavg_7=np.divide(chol_conan_7, chol_nummeet_7, out=np.zeros_like(chol_conan_7), where=chol_nummeet_7!=0)
chol_meetavg_8=np.divide(chol_conan_8, chol_nummeet_8, out=np.zeros_like(chol_conan_8), where=chol_nummeet_8!=0)
chol_meetavg_9=np.divide(chol_conan_9, chol_nummeet_9, out=np.zeros_like(chol_conan_9), where=chol_nummeet_9!=0)
chol_meetavg_10=np.divide(chol_conan_10, chol_nummeet_10, out=np.zeros_like(chol_conan_10), where=chol_nummeet_10!=0)
# Out:
# <ipython-input-65-0a618f050c48>:1: FutureWarning: Calling a ufunc on non-aligned DataFrames (or DataFrame/Series combination). Currently, the indices are ignored and the result takes the index/columns of the first DataFrame. In the future , the DataFrames/Series will be aligned before applying the ufunc.
# Convert one of the arguments to a NumPy array (eg 'ufunc(df1, np.asarray(df2)') to keep the current behaviour, or align manually (eg 'df1, df2 = df1.align(df2)') before passing to the ufunc to obtain the future behaviour and silence this warning.
#   chol_meetavg_1=np.divide(chol_conan_1, chol_nummeet_1, out=np.zeros_like(chol_conan_1), where=chol_nummeet_1!=0)
# <ipython-input-65-0a618f050c48>:2: FutureWarning: Calling a ufunc on non-aligned DataFrames (or DataFrame/Series combination). Currently, the indices are ignored and the result takes the index/columns of the first DataFrame. In the future , the DataFrames/Series will be aligned before applying the ufunc.
# ...

# %%
no_chol_meetavg_1=np.divide(no_chol_conan_1, no_chol_nummeet_1, out=np.zeros_like(no_chol_conan_1), where=no_chol_nummeet_1!=0)
no_chol_meetavg_2=np.divide(no_chol_conan_2, no_chol_nummeet_2, out=np.zeros_like(no_chol_conan_2), where=no_chol_nummeet_2!=0)
no_chol_meetavg_3=np.divide(no_chol_conan_3, no_chol_nummeet_3, out=np.zeros_like(no_chol_conan_3), where=no_chol_nummeet_3!=0)
no_chol_meetavg_4=np.divide(no_chol_conan_4, no_chol_nummeet_4, out=np.zeros_like(no_chol_conan_4), where=no_chol_nummeet_4!=0)
no_chol_meetavg_5=np.divide(no_chol_conan_5, no_chol_nummeet_5, out=np.zeros_like(no_chol_conan_5), where=no_chol_nummeet_5!=0)
no_chol_meetavg_6=np.divide(no_chol_conan_6, no_chol_nummeet_6, out=np.zeros_like(no_chol_conan_6), where=no_chol_nummeet_6!=0)
no_chol_meetavg_7=np.divide(no_chol_conan_7, no_chol_nummeet_7, out=np.zeros_like(no_chol_conan_7), where=no_chol_nummeet_7!=0)
no_chol_meetavg_8=np.divide(no_chol_conan_8, no_chol_nummeet_8, out=np.zeros_like(no_chol_conan_8), where=no_chol_nummeet_8!=0)
no_chol_meetavg_9=np.divide(no_chol_conan_9, no_chol_nummeet_9, out=np.zeros_like(no_chol_conan_9), where=no_chol_nummeet_9!=0)
no_chol_meetavg_10=np.divide(no_chol_conan_10, no_chol_nummeet_10, out=np.zeros_like(no_chol_conan_10), where=no_chol_nummeet_10!=0)
# Out:
# <ipython-input-66-ee518016d879>:1: FutureWarning: Calling a ufunc on non-aligned DataFrames (or DataFrame/Series combination). Currently, the indices are ignored and the result takes the index/columns of the first DataFrame. In the future , the DataFrames/Series will be aligned before applying the ufunc.
# Convert one of the arguments to a NumPy array (eg 'ufunc(df1, np.asarray(df2)') to keep the current behaviour, or align manually (eg 'df1, df2 = df1.align(df2)') before passing to the ufunc to obtain the future behaviour and silence this warning.
#   no_chol_meetavg_1=np.divide(no_chol_conan_1, no_chol_nummeet_1, out=np.zeros_like(no_chol_conan_1), where=no_chol_nummeet_1!=0)
# <ipython-input-66-ee518016d879>:2: FutureWarning: Calling a ufunc on non-aligned DataFrames (or DataFrame/Series combination). Currently, the indices are ignored and the result takes the index/columns of the first DataFrame. In the future , the DataFrames/Series will be aligned before applying the ufunc.
# ...

# %%
chol_meetavg_agg=700*0.1*((chol_meetavg_1+chol_meetavg_2+chol_meetavg_3+chol_meetavg_4+chol_meetavg_5+chol_meetavg_6+chol_meetavg_7+chol_meetavg_8+chol_meetavg_9+chol_meetavg_10).to_numpy().reshape((1752,1752)))
no_chol_meetavg_agg=700*0.1*((no_chol_meetavg_1+no_chol_meetavg_2+no_chol_meetavg_3+no_chol_meetavg_4+no_chol_meetavg_5+no_chol_meetavg_6+no_chol_meetavg_7+no_chol_meetavg_8+no_chol_meetavg_9+no_chol_meetavg_10).to_numpy().reshape((1752,1752)))

# %%
chol_meetavg_agg_sem=700*stats.sem(np.concatenate((chol_meetavg_1,chol_meetavg_2,chol_meetavg_3,chol_meetavg_4,chol_meetavg_5,chol_meetavg_6,chol_meetavg_7,chol_meetavg_8,chol_meetavg_9,chol_meetavg_10),axis=1),axis=1).reshape((1752,1752))
no_chol_meetavg_agg_sem=700*stats.sem(np.concatenate((no_chol_meetavg_1,no_chol_meetavg_2,no_chol_meetavg_3,no_chol_meetavg_4,no_chol_meetavg_5,no_chol_meetavg_6,no_chol_meetavg_7,no_chol_meetavg_8,no_chol_meetavg_9,no_chol_meetavg_10),axis=1),axis=1).reshape((1752,1752))

# %%
meetavg_symme_chol=0.5*(chol_meetavg_agg[219*6:219*7,0:219]+np.transpose(chol_meetavg_agg[219*5:219*6,219*3:219*4]))
meetavg_symme_no_chol=0.5*(no_chol_meetavg_agg[219*6:219*7,0:219]+np.transpose(no_chol_meetavg_agg[219*5:219*6,219*3:219*4]))
meetavg_no_symme_chol=0.5*(chol_meetavg_agg[219*6:219*7,219*3:219*4]+np.transpose(chol_meetavg_agg[219*6:219*7,219*3:219*4]) )  
meetavg_no_symme_no_chol=0.5*(no_chol_meetavg_agg[219*6:219*7,219*3:219*4]+np.transpose(no_chol_meetavg_agg[219*6:219*7,219*3:219*4]))

# %%
# assuming convariance =! 0
#
#
#
meetavg_symme_chol_sem=0.5*np.sqrt(chol_meetavg_agg_sem[219*6:219*7,0:219]**2+np.transpose(chol_meetavg_agg_sem[219*5:219*6,219*3:219*4])**2)
meetavg_symme_no_chol_sem=0.5*np.sqrt(no_chol_meetavg_agg_sem[219*6:219*7,0:219]**2+np.transpose(no_chol_meetavg_agg_sem[219*5:219*6,219*3:219*4])**2)
meetavg_no_symme_chol_sem=0.5*np.sqrt(chol_meetavg_agg_sem[219*6:219*7,219*3:219*4]**2+np.transpose(chol_meetavg_agg_sem[219*6:219*7,219*3:219*4])**2)  
meetavg_no_symme_no_chol_sem=0.5*np.sqrt(no_chol_meetavg_agg_sem[219*6:219*7,219*3:219*4]**2+np.transpose(no_chol_meetavg_agg_sem[219*6:219*7,219*3:219*4])**2)

# %%
print(np.max(chol_meetavg_agg_sem[219*6:219*7,0:219]**2))
print(np.max(chol_meetavg_agg_sem[219*6:219*7,0:219]))
# Out:
# 0.044163269156524895
# 0.21015058685743634

# %%
! rm meetavg_symme_automatic.txt
for a,b in (np.transpose((np.absolute((meetavg_symme_chol-meetavg_symme_no_chol))>0.001).nonzero())).tolist() :
    resid1, resid2=np.remainder([a,b],219)+[6,6]
    value=(meetavg_symme_chol-meetavg_symme_no_chol)[a,b]
    #value_sem=(0.5*np.sqrt(meetavg_symme_chol_sem**2+meetavg_symme_no_chol_sem**2-2*meetavg_symme_chol_sem*meetavg_symme_no_chol_sem))[a,b]
    value_sem=(0.5*np.sqrt(meetavg_symme_chol_sem**2+meetavg_symme_no_chol_sem**2))[a,b]
    v_chol=meetavg_symme_chol[a,b]
    v_chol_sem=meetavg_symme_chol_sem[a,b]
    v_no_chol=meetavg_symme_no_chol[a,b]
    v_no_chol_sem=meetavg_symme_no_chol_sem[a,b]
    res1_name=residue_names.loc[[resid1]].values[0][0]
    res2_name=residue_names.loc[[resid2]].values[0][0]
    x=residue_names.loc[[resid1]].values[0][1]
    y=residue_names.loc[[resid1]].values[0][2]
    z=residue_names.loc[[resid1]].values[0][3]
    if y>90 or x<80:
        if z>45:
            color="black"
        else:
            color="white"  #not grey anymore
    else:
        color="white"
    #print('{}{}\t{}{}\t= {}'.format(res1_name,resid1,res2_name,resid2,value))
    with open('meetavg_symme_automatic.txt', 'a') as f:
        f.write('{}{}\t{}{}\t{}\t{}\t{}\t{}\t{}\t{}\t{}\t{}\t{}\t{}\n'.format(res1_name,resid1,res2_name,resid2,value,v_chol,v_no_chol,color,value_sem,v_chol_sem,v_no_chol_sem,"symme",a,b))

# %%
res = []
[res.append(x) for x in np.sort(np.transpose((np.absolute((meetavg_no_symme_chol-meetavg_no_symme_no_chol))>0.001).nonzero())).tolist() if x not in res]
for a,b in res :
    resid1, resid2=np.remainder([a,b],219)+[6,6]
    value=(meetavg_no_symme_chol-meetavg_no_symme_no_chol)[a,b]
    #value_sem=(0.5*np.sqrt(meetavg_no_symme_chol_sem**2+meetavg_no_symme_no_chol_sem**2-2*meetavg_no_symme_chol_sem*meetavg_no_symme_no_chol_sem))[a,b]
    value_sem=(0.5*np.sqrt(meetavg_no_symme_chol_sem**2+meetavg_no_symme_no_chol_sem**2))[a,b]
    v_chol=meetavg_no_symme_chol[a,b]
    v_chol_sem=meetavg_no_symme_chol_sem[a,b]
    v_no_chol=meetavg_no_symme_no_chol[a,b]
    v_no_chol_sem=meetavg_no_symme_no_chol_sem[a,b]
    res1_name=residue_names.loc[[resid1]].values[0][0]
    res2_name=residue_names.loc[[resid2]].values[0][0]
    x=residue_names.loc[[resid1]].values[0][1]
    y=residue_names.loc[[resid1]].values[0][2]
    z=residue_names.loc[[resid1]].values[0][3]
    #print(z)
    if y>90 or x<80:
        if z>45:
            color="black"
        else:
            color="white"  #not grey anymore
    else:
        color="white"
    #print('{}{}\t{}{}\t= {}'.format(res1_name,resid1,res2_name,resid2,value))
    with open('meetavg_symme_automatic.txt', 'a') as f:
        f.write('{}{}\t{}{}\t{}\t{}\t{}\t{}\t{}\t{}\t{}\t{}\t{}\t{}\n'.format(res1_name,resid1,res2_name,resid2,value,v_chol,v_no_chol,color,value_sem,v_chol_sem,v_no_chol_sem,"nosym",a,b))

# %%
meetavg_symme_contacts=pd.read_csv('meetavg_symme_automatic.txt', delimiter="\t", header=None)

# %%
plt.figure(figsize=(16,16))
#plt.imshow(chol_conan_agg.clip(0,0.1), cmap='inferno_r', interpolation='none')
plt.imshow(meetavg_symme_chol, cmap='inferno_r', interpolation='none')
plt.colorbar()
plt.show()
plt.figure(figsize=(16,16))
#plt.imshow(no_chol_conan_agg.clip(0,0.1), cmap='inferno_r', interpolation='none')
plt.imshow(meetavg_symme_no_chol, cmap='inferno_r', interpolation='none')
plt.colorbar()
plt.show()

# %%
meetavg_symme_contacts.sort_values(by=4)
# Out:
#         0       1         2         3         4      5         6         7   \
# 48  VAL203  ARG196  0.005715  0.005715  0.000000  white  0.002857  0.005715
# 31  GLN129  PRO110  0.007000  0.007000  0.000000  black  0.003500  0.007000
# 32  GLN129  ARG113  0.092562  0.092562  0.000000  black  0.006124  0.012247
# 33  ILE132  ALA102  0.027327  0.027327  0.000000  black  0.005583  0.011166
# 34  ILE132  VAL103  0.010010  0.010010  0.000000  black  0.003337  0.006673
# ..     ...     ...       ...       ...       ...    ...       ...       ...
# 3    VAL77   TRP10 -0.031017  0.213431  0.244448  white  0.054820  0.090981
# 66  LEU217   PHE14 -0.175992  0.224152  0.400144  white  0.041871  0.033780
# 64  LEU217   TRP10 -0.133636  0.731388  0.865024  white  0.206189  0.348615
# 47  TRP202  ARG196 -0.472001  0.725557  1.197558  white  0.286898  0.199469
# 91  PHE221  PHE221 -0.317672  0.937263  1.254935  white  0.209562  0.223775
#
#           8      9    10   11
# ...

# %%
nombres=meetavg_symme_contacts.sort_values(by=2)[[0,1]].agg('-'.join, axis=1)

plt.figure(figsize=(16,12))
plt.bar(
    x=np.arange(meetavg_symme_contacts.shape[0]),
    height=meetavg_symme_contacts.sort_values(by=2)[2],
    tick_label=nombres,
    color=meetavg_symme_contacts.sort_values(by=2)[5]
)
plt.xticks(rotation=70,fontsize=16,horizontalalignment="right")#,position=(-0.9,-0.15),rotation_mode="anchor") #horizontalalignment="right")
plt.yticks(fontsize=24)
plt.tick_params(axis='both', which='both', labelsize=32, length=6, width=4)
plt.ylabel("Difference in interaction time",fontsize=36,loc="top")
plt.savefig("conan_difference_meetavg.png", bbox_inches="tight")

# %% [markdown]
# # Addendum Camilo

# %%
! rm symme_automatic_2.txt
for a,b in (np.transpose((np.absolute((symme_chol-symme_no_chol))>0.01).nonzero())).tolist() :
    resid1, resid2=np.remainder([a,b],219)+[6,6]
    #value=(meetavg_symme_chol-meetavg_symme_no_chol)[a,b]
    value=(symme_chol-symme_no_chol)[a,b]
    #value_sem=(0.5*np.sqrt(meetavg_symme_chol_sem**2+meetavg_symme_no_chol_sem**2-2*meetavg_symme_chol_sem*meetavg_symme_no_chol_sem))[a,b]
    value_sem=(0.5*np.sqrt(meetavg_symme_chol_sem**2+meetavg_symme_no_chol_sem**2))[a,b]
    v_chol=meetavg_symme_chol[a,b]
    v_chol_sem=meetavg_symme_chol_sem[a,b]
    v_no_chol=meetavg_symme_no_chol[a,b]
    v_no_chol_sem=meetavg_symme_no_chol_sem[a,b]
    res1_name=residue_names.loc[[resid1]].values[0][0]
    res2_name=residue_names.loc[[resid2]].values[0][0]
    x=residue_names.loc[[resid1]].values[0][1]
    y=residue_names.loc[[resid1]].values[0][2]
    z=residue_names.loc[[resid1]].values[0][3]
    if y>90 or x<80:
        if z>45:
            color="grey"  # freed so we might use instead of black
        else:
            color="white"  #not grey anymore
    else:
        color="white"
    #print('{}{}\t{}{}\t= {}'.format(res1_name,resid1,res2_name,resid2,value))
    with open('symme_automatic_2.txt', 'a') as f:
        f.write('{}{}\t{}{}\t{}\t{}\t{}\t{}\t{}\t{}\t{}\t{}\t{}\t{}\n'.format(res1_name,resid1,res2_name,resid2,value,v_chol,v_no_chol,color,value_sem,v_chol_sem,v_no_chol_sem,"symme",a,b))

# %%
res = []
[res.append(x) for x in np.sort(np.transpose((np.absolute((no_symme_chol-no_symme_no_chol))>0.01).nonzero())).tolist() if x not in res]
for a,b in res :
    resid1, resid2=np.remainder([a,b],219)+[6,6]
    #value=(meetavg_no_symme_chol-meetavg_no_symme_no_chol)[a,b]
    value=(no_symme_chol-no_symme_no_chol)[a,b]
    #value_sem=(0.5*np.sqrt(meetavg_no_symme_chol_sem**2+meetavg_no_symme_no_chol_sem**2-2*meetavg_no_symme_chol_sem*meetavg_no_symme_no_chol_sem))[a,b]
    value_sem=(0.5*np.sqrt(meetavg_no_symme_chol_sem**2+meetavg_no_symme_no_chol_sem**2))[a,b]
    v_chol=meetavg_no_symme_chol[a,b]
    v_chol_sem=meetavg_no_symme_chol_sem[a,b]
    v_no_chol=meetavg_no_symme_no_chol[a,b]
    v_no_chol_sem=meetavg_no_symme_no_chol_sem[a,b]
    res1_name=residue_names.loc[[resid1]].values[0][0]
    res2_name=residue_names.loc[[resid2]].values[0][0]
    x=residue_names.loc[[resid1]].values[0][1]
    y=residue_names.loc[[resid1]].values[0][2]
    z=residue_names.loc[[resid1]].values[0][3]
    #print(z)
    if y>90 or x<80:
        if z>45:
            color="grey"  # freed so we might use instead of black
        else:
            color="white"  #not grey anymore
    else:
        color="white"
    #print('{}{}\t{}{}\t= {}'.format(res1_name,resid1,res2_name,resid2,value))
    with open('symme_automatic_2.txt', 'a') as f:
        f.write('{}{}\t{}{}\t{}\t{}\t{}\t{}\t{}\t{}\t{}\t{}\t{}\t{}\n'.format(res1_name,resid1,res2_name,resid2,value,v_chol,v_no_chol,color,value_sem,v_chol_sem,v_no_chol_sem,"nosym",a,b))

# %%
symme_contacts_2=pd.read_csv('symme_automatic_2.txt', delimiter="\t", header=None)
symme_contacts_2.sort_values(by=2)
# Out:
#         0       1         2         3         4      5         6         7   \
# 12  LEU217   PHE14 -0.126853  0.224152  0.400144  white  0.041871  0.033780
# 10  ILE210   LEU95 -0.107070  0.203170  0.240725  white  0.014540  0.015584
# 11  LEU217   TRP10 -0.090387  0.731388  0.865024  white  0.206189  0.348615
# 19  PHE221  PHE221 -0.077703  0.937263  1.254935  white  0.209562  0.223775
# 0    VAL77   TRP10 -0.051807  0.213431  0.244448  white  0.054820  0.090981
# 14  PHE221    ALA7 -0.034809  0.094602  0.095984  white  0.033026  0.044725
# 13  PHE221    SER6 -0.033267  0.147344  0.150037  white  0.041602  0.057928
# 15  PHE221   TRP10 -0.026353  0.166793  0.177331  white  0.051764  0.049353
# 21  PHE221  PHE224 -0.016512  0.040689  0.192183  white  0.050792  0.014895
# 9   TRP202  ARG196 -0.016455  0.725557  1.197558  white  0.286898  0.199469
# 20  PHE221  LEU222 -0.013762  0.174337  0.115913  white  0.038099  0.049360
# ...

# %%
nombres=symme_contacts_2.sort_values(by=2)[[0,1]].agg('-'.join, axis=1)
plt.figure(figsize=(16,12))
plt.bar(
    x=np.arange(symme_contacts_2.shape[0]),
    height=symme_contacts_2.sort_values(by=2)[3],  #3 and 4 instead of 2
    tick_label=nombres,
    color=symme_contacts_2.sort_values(by=2)[5]
)
plt.xticks(rotation=70,fontsize=16,horizontalalignment="right")#,position=(-0.9,-0.15),rotation_mode="anchor") #horizontalalignment="right")
plt.yticks(fontsize=24)
plt.tick_params(axis='both', which='both', labelsize=32, length=6, width=4)
plt.ylabel(r"$<\tau>_{ij}$ (ns)",fontsize=36)#,loc="top")
plt.savefig("conan_notdifference_fix.png", bbox_inches="tight")

# %%
reference=max(meetavg_symme_chol.max(),meetavg_symme_no_chol.max(),meetavg_no_symme_chol.max(),meetavg_no_symme_no_chol.max())

nombres=symme_contacts.sort_values(by=2)[[0,1]].agg('-'.join, axis=1)
plt.figure(figsize=(16,5))
#plt.bar(
#    x=np.arange(symme_contacts_2.shape[0]),
#    height=symme_contacts_2.sort_values(by=2)[3],  #3 and 4 instead of 2
#    tick_label=nombres,
#    color=symme_contacts_2.sort_values(by=2)[5]
#)
plt.plot(symme_contacts_2.sort_values(by=2)[3].tolist(),color="blue",label="Chol",lw=5)
plt.plot(symme_contacts_2.sort_values(by=2)[4].tolist(),color="lime",label="SM",lw=5)
plt.hlines(y=reference,xmin=-0.7,xmax=21.7,lw=5,ls="--",color="black")

plt.xticks(np.arange(22),nombres,rotation=70,fontsize=16,horizontalalignment="right")#,position=(-0.9,-0.15),rotation_mode="anchor") #horizontalalignment="right")
plt.yticks(fontsize=24)
plt.ylim(-0.01,1.3)
plt.xlim(-0.7,21.7)
plt.legend(loc='upper center',fontsize=24)
plt.tick_params(axis='both', which='both', labelsize=32, length=6, width=4)
plt.ylabel(r"$<\tau>_{ij}$ (ns)",fontsize=36)#,loc="top")
plt.savefig("conan_notdifference_fix.png", bbox_inches="tight")

# %%
reference=max(meetavg_symme_chol.max(),meetavg_symme_no_chol.max(),meetavg_no_symme_chol.max(),meetavg_no_symme_no_chol.max())

nombres=symme_contacts.sort_values(by=2)[[0,1]].agg('-'.join, axis=1)
plt.figure(figsize=(16,5))
#plt.bar(
#    x=np.arange(symme_contacts_2.shape[0]),
#    height=symme_contacts_2.sort_values(by=2)[3],  #3 and 4 instead of 2
#    tick_label=nombres,
#    color=symme_contacts_2.sort_values(by=2)[5]
#)
plt.errorbar(x=np.arange(22),y=symme_contacts_2.sort_values(by=2)[3].tolist(),yerr=symme_contacts_2.sort_values(by=2)[7].tolist(),color="blue",label="Chol",lw=3,capsize=5,elinewidth=3,capthick=3)
plt.errorbar(x=np.arange(22),y=symme_contacts_2.sort_values(by=2)[4].tolist(),yerr=symme_contacts_2.sort_values(by=2)[8].tolist(),color="lime",label="SM",lw=3,capsize=5,elinewidth=3,capthick=3)
plt.hlines(y=reference,xmin=-0.7,xmax=21.7,lw=5,ls="--",color="black")

plt.xticks(np.arange(22),nombres,rotation=70,fontsize=16,horizontalalignment="right")#,position=(-0.9,-0.15),rotation_mode="anchor") #horizontalalignment="right")
plt.yticks(fontsize=24)
plt.ylim(-0.01,1.8)
plt.xlim(-0.7,21.7)
plt.legend(loc='upper right',fontsize=24)
plt.tick_params(axis='both', which='both', labelsize=32, length=6, width=4)
plt.ylabel(r"$<\tau>_{ij}$ (ns)",fontsize=36)#,loc="top")
plt.savefig("conan_notdifference_fix.png", bbox_inches="tight")

# %%
reference=max(symme_chol.max(),symme_no_chol.max(),no_symme_chol.max(),no_symme_no_chol.max())
nombres=symme_contacts.sort_values(by=2)[[0,1]].agg('-'.join, axis=1)
plt.figure(figsize=(16,5))

plt.plot(symme_contacts.sort_values(by=2)[3].tolist(),color="blue",label="Chol",lw=5)
plt.plot(symme_contacts.sort_values(by=2)[4].tolist(),color="lime",label="SM",lw=5)
plt.hlines(y=reference,xmin=-0.7,xmax=21.7,lw=5,ls="--",color="black")

plt.xticks(np.arange(22),nombres,rotation=70,fontsize=16,horizontalalignment="right")#,position=(-0.9,-0.15),rotation_mode="anchor") #horizontalalignment="right")
plt.yticks(fontsize=24)
#plt.ylim(-0.05,43)
plt.xlim(-0.7,21.7)
plt.legend(loc='upper right',fontsize=24)
plt.tick_params(axis='both', which='both', labelsize=32, length=6, width=4)
plt.ylabel(r"$T_{ij}$ (% of time)",fontsize=36)#,loc="top")
plt.savefig("conan_F.png", bbox_inches="tight")

# %%
reference=max(symme_chol.max(),symme_no_chol.max(),no_symme_chol.max(),no_symme_no_chol.max())
nombres=symme_contacts.sort_values(by=2)[[0,1]].agg('-'.join, axis=1)

plt.figure(figsize=(16,5))
#plt.bar(
#    x=np.arange(symme_contacts_2.shape[0]),
#    height=symme_contacts_2.sort_values(by=2)[3],  #3 and 4 instead of 2
#    tick_label=nombres,
#    color=symme_contacts_2.sort_values(by=2)[5]
#)
plt.errorbar(x=np.arange(22),y=symme_contacts.sort_values(by=2)[3].tolist(),yerr=symme_contacts.sort_values(by=2)[7].tolist(),color="blue",label="Chol",lw=3,capsize=5,elinewidth=3,capthick=3)
plt.errorbar(x=np.arange(22),y=symme_contacts.sort_values(by=2)[4].tolist(),yerr=symme_contacts.sort_values(by=2)[8].tolist(),color="lime",label="SM",lw=3,capsize=5,elinewidth=3,capthick=3)
plt.hlines(y=reference,xmin=-0.7,xmax=21.7,lw=5,ls="--",color="black")

plt.xticks(np.arange(22),nombres,rotation=70,fontsize=16,horizontalalignment="right")#,position=(-0.9,-0.15),rotation_mode="anchor") #horizontalalignment="right")
plt.yticks(fontsize=24)
#plt.ylim(-0.3,52)
plt.ylim(-0.003,0.52)
plt.xlim(-0.7,21.7)
plt.legend(loc='upper right',fontsize=24)
plt.tick_params(axis='both', which='both', labelsize=32, length=6, width=4)
plt.ylabel(r"$T_{ij}$ (a.u.)",fontsize=36)#,loc="top")
plt.savefig("conan_F.png", bbox_inches="tight")
